# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
from pandas.io.json import json_normalize

plt.style.use('ggplot')
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']  #解决seaborn中文字体显示问题
plt.rc('figure', figsize=(10, 10))  #把plt默认的图片size调大一点
plt.rcParams["figure.dpi"] =mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
# %matplotlib inline

# %%
conn = MongoClient(host='127.0.0.1', port=27017)  # 实例化MongoClient
db = conn.get_database('Lianjia')  # 连接到Lianjia数据库

zufang = db.get_collection('zufang') # 连接到集合zufang
mon_data = zufang.find()  # 查询这个集合下的所有记录

# %%
data = json_normalize([comment for comment in mon_data])#解析这个json

# %%
data.head()
# Out:
#                         _id bathroom_num bedroom_num bizcircle_name city dist  \
# 0  5d1a090c38a4e51e8e5e0591            2           3            世纪城   北京   海淀
# 1  5d1a090d38a4e51e8e5e0593            2           3            世纪城   北京   海淀
# 2  5d1a090d38a4e51e8e5e0595            1           2            世纪城   北京   海淀
# 3  5d1a090e38a4e51e8e5e0597            2           3            世纪城   北京   海淀
# 4  5d1a090f38a4e51e8e5e0599            2           3            世纪城   北京   海淀
#
#   distance frame_orientation hall_num             house_tag  \
# 0      721                 南        2           近地铁 集中供暖 新上
# 1      828                东南        2       精装 集中供暖 双卫生间 新上
# 2      724                东南        1         近地铁 集中供暖 随时看房
# 3     1101               南 北        2  精装 集中供暖 双卫生间 新上 随时看房
# 4      873             东 南 北        2           近地铁 集中供暖 新上
#
#          house_title   latitude  layout   longitude  \
# 0         垂虹园 3室2厅 南  39.967021  3室2厅2卫  116.293479
# 1   整租·远大园五区 3室2厅 东南  39.959175  3室2厅2卫  116.289427
# 2      远大园四区 2室1厅 东南  39.959747  2室1厅1卫  116.292721
# 3  整租·远大园一区 3室2厅 南/北  39.961689  3室2厅2卫  116.285995
# 4     春荫园 3室2厅 东/南/北  39.968979  3室2厅2卫  116.288287
#
#                                                m_url rent_area  \
# 0  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...       164
# 1  https://m.lianjia.com/chuzu/bj/zufang/BJ228955...       152
# 2  https://m.lianjia.com/chuzu/bj/zufang/BJ228178...        85
# 3  https://m.lianjia.com/chuzu/bj/zufang/BJ228759...       165
# 4  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...       162
#
#   rent_price_listing rent_price_unit resblock_name type
# 0              21000             元/月           垂虹园   整租
# 1              18000             元/月         远大园五区   整租
# 2               8500             元/月         远大园四区   整租
# 3              18000             元/月         远大园一区   整租
# 4              18000             元/月           春荫园   整租

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92604 entries, 0 to 92603
# Data columns (total 20 columns):
# _id                   92604 non-null object
# bathroom_num          92604 non-null object
# bedroom_num           92604 non-null object
# bizcircle_name        92604 non-null object
# city                  92604 non-null object
# dist                  92604 non-null object
# distance              48998 non-null object
# frame_orientation     92604 non-null object
# hall_num              92604 non-null object
# house_tag             73133 non-null object
# house_title           92604 non-null object
# latitude              92604 non-null object
# layout                92604 non-null object
# longitude             92604 non-null object
# m_url                 92604 non-null object
# rent_area             92604 non-null object
# rent_price_listing    92604 non-null object
# rent_price_unit       92604 non-null object
# resblock_name         92604 non-null object
# type                  92604 non-null object
# dtypes: object(20)
# memory usage: 14.1+ MB

# %%
# 每个城市各采样3000条数据，保存为csv文件
data_sample = pd.concat([data[data['city']==city].sample(3000) for city in ['北京', '上海', '广州', '深圳']])##pd.concat拼接df
data_sample.to_csv('data_sample.csv', index=False)

# %%
# 数据清洗(按列清理)
# 1. 去掉“_id”列
data = data.drop(columns='_id')

# %%
# 2. bathroom_num
data['bathroom_num'].unique()#查看bathroom_num有什么值##unique
# Out:
# array(['2', '1', '0', '4', '3', '5', '6', '7', '9', '8'], dtype=object)

# %%
data[data['bathroom_num'].isin(['8','9','11'])]#查看bathroom_num=8/9/11的数据##isin
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 8738             9           9            北七家   北京   昌平     None
# 20243            9          10             花木   上海   浦东      404
# 22629            8           7             唐镇   上海   浦东     None
# 23845            9          20             张江   上海   浦东     None
# 23978            8           6             张江   上海   浦东     None
# 24064            8           7             祝桥   上海   浦东     None
# 31156            8           8           莘闵别墅   上海   松江     None
# 33518            8           8             赵巷   上海   青浦     None
# 37104            8           1            科学城   广州   增城     None
# 56929            8           9          白云大道南   广州   白云      594
# 60301            9           9             南湖   广州   白云     None
# 63423            8           9            凤凰城   广州   增城     None
# 76157            8           7             梅沙   深圳  盐田区     None
# 78384            8           6             曦城   深圳  宝安区     None
# 91449            8           8             坂田   深圳  龙岗区     None
#
#       frame_orientation hall_num house_tag           house_title   latitude  \
# 8738            东 南 西 北        5        精装  整租·麦卡伦地 9室5厅 东/南/西/北  40.146554
# 20243                 南        5       近地铁      花木路1701号 10室5厅 南  31.220902
# 22629                 南        2      None           白金瀚宫 7室2厅 南  31.231396
# 23845                 南        9      None         汇洋北宿舍 20室9厅 南  31.166592
# 23978                 北        2      None   整租·汤臣高尔夫(别墅) 6室2厅 北  31.225384
# 24064               南 北        3      None         东海御庭 7室3厅 南/北  31.214139
# 31156                 南        4      None          桃花源田庄 8室4厅 南  31.101212
# 33518                          6      None           整租·香水湾 8室6厅  31.158286
# 37104                 南        1      None       保利越秀岭南林语 1室1厅 南  23.218326
# 56929               南 北        3       近地铁        珠江岭南苑 9室3厅 南/北  23.202732
# 60301                东南        5      None       整租·南湖庄园 9室5厅 东南  23.217537
# 63423                 南        3      None      碧桂园凤凰城凤凰苑 9室3厅 南  23.138568
# 76157                东南        3      None         万科东海岸 7室3厅 东南  22.607979
# 78384             东南 西北        3      None  招商华侨城曦城四期 6室3厅 东南/西北   22.60085
# 91449                 东        2      随时看房    合租·万科城三期 8居室 跃层 东卧  22.650988
#
#         layout   longitude                                              m_url  \
# 8738    9室5厅9卫  116.418277  https://m.lianjia.com/chuzu/bj/zufang/BJ203027...
# 20243  10室5厅9卫  121.570658  https://m.lianjia.com/chuzu/sh/zufang/SH212387...
# 22629   7室2厅8卫  121.665375  https://m.lianjia.com/chuzu/sh/zufang/SH222508...
# 23845  20室9厅9卫  121.643936  https://m.lianjia.com/chuzu/sh/zufang/SH226792...
# 23978   6室2厅8卫    121.5882  https://m.lianjia.com/chuzu/sh/zufang/SH222538...
# 24064   7室3厅8卫  121.776494  https://m.lianjia.com/chuzu/sh/zufang/SH206789...
# 31156   8室4厅8卫  121.354455  https://m.lianjia.com/chuzu/sh/zufang/SH219030...
# 33518   8室6厅8卫  121.248358  https://m.lianjia.com/chuzu/sh/zufang/SH192424...
# 37104   1室1厅8卫  113.508152  https://m.lianjia.com/chuzu/gz/zufang/GZ225989...
# 56929   9室3厅8卫  113.286666  https://m.lianjia.com/chuzu/gz/zufang/GZ202798...
# 60301   9室5厅9卫  113.332386  https://m.lianjia.com/chuzu/gz/zufang/GZ219970...
# 63423   9室3厅8卫  113.588147  https://m.lianjia.com/chuzu/gz/zufang/GZ213605...
# 76157   7室3厅8卫   114.30681  https://m.lianjia.com/chuzu/sz/zufang/SZ223452...
# 78384   6室3厅8卫   113.91623  https://m.lianjia.com/chuzu/sz/zufang/SZ210364...
# 91449   8室2厅8卫  114.077847  https://m.lianjia.com/chuzu/sz/zufang/SZ223046...
#
#       rent_area rent_price_listing rent_price_unit resblock_name type
# 8738        544              45000             元/月          麦卡伦地   整租
# 20243       581             330000             元/月      花木路1701号   整租
# 22629       483              70000             元/月          白金瀚宫   整租
# 23845      5600             369600             元/月         汇洋北宿舍   整租
# 23978       417              60000             元/月     汤臣高尔夫(别墅)   整租
# 24064       767              16000             元/月          东海御庭   整租
# 31156       504              36000             元/月         桃花源田庄   整租
# 33518       498              30000             元/月           香水湾   整租
# 37104      1500             120000             元/月      保利越秀岭南林语   整租
# 56929       500              80000             元/月         珠江岭南苑   整租
# 60301      1100              50000             元/月          南湖庄园   整租
# 63423       850              88000             元/月     碧桂园凤凰城凤凰苑   整租
# 76157       268              42000             元/月         万科东海岸   整租
# 78384       418             100000             元/月     招商华侨城曦城四期   整租
# 91449       118               2000             元/月         万科城三期   合租

# %%
# 除了55273行是异常数据外，其它数据都正常
#data = data.drop([55273])

# %%
# 3. bedroom_num
data['bedroom_num'].unique()#查看bedroom_num有什么值
# Out:
# array(['3', '2', '1', '4', '5', '6', '0', '7', '9', '8', '15', '11', '10',
#        '20', '12'], dtype=object)

# %%
# 没有异常数据，只是很多10室以上都是专门用来合租的
data[data['bedroom_num'].isin(['10','11','12','13','14','15','20'])]
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 17627            2          15             西郊   上海   长宁     None
# 17748            4          11            新华路   上海   长宁     None
# 18218            5          10           中山公园   上海   长宁      531
# 20243            9          10             花木   上海   浦东      404
# 23845            9          20             张江   上海   浦东     None
# 27569            3          10             航华   上海   闵行      432
# 40074            3          11            天润路   广州   天河      838
# 47757            1          10            滨江中   广州   海珠      557
# 47760            1          10            滨江中   广州   海珠      557
# 51608            1          15             会江   广州   番禺     None
# 51748            2          10             汉溪   广州   番禺      562
# 51893            3          12             汉溪   广州   番禺      562
# 72856            5          10            华侨城   深圳  南山区     1007
# 76503            4          11           宝安中心   深圳  宝安区      188
#
#       frame_orientation hall_num house_tag             house_title  \
# 17627                 南        2      None          金庭庄园酒店 15室2厅 南
# 17748                 南        3    近地铁 精装         整租·大境别墅 11室3厅 南
# 18218                 南        3       近地铁     整租·定西路1235弄 10室3厅 南
# 20243                 南        5       近地铁        花木路1701号 10室5厅 南
# 23845                 南        9      None           汇洋北宿舍 20室9厅 南
# 27569       东 东南 南 西南 西        3      None  沪光小区 10室3厅 东/东南/南/西南/西
# 40074                 南        3       近地铁           协和新世界 11室3厅 南
# 47757           东 南 西 北        0       近地铁      滨江中路 10室0厅 东/南/西/北
# 47760           东 南 西 北        1       近地铁      滨江中路 10室1厅 东/南/西/北
# 51608                 南        1        精装       整租·敏捷御峰国际 15室1厅 南
# 51748                东南        2       近地铁          保利大都汇 10室2厅 东南
# 51893                东南        3       近地铁          保利大都汇 12室3厅 东南
# 72856                 南        4       近地铁      名商高尔夫球会 10室4厅 复式 南
# 76503                 南        1       近地铁      金泓凯旋城二期 11室1厅 复式 南
#
#           latitude   layout    longitude  \
# 17627   31.2102489  15室2厅2卫  121.3635752
# 17748    31.212721  11室3厅4卫   121.436966
# 18218  31.22102198  10室3厅5卫  121.4288858
# 20243    31.220902  10室5厅9卫   121.570658
# 23845    31.166592  20室9厅9卫   121.643936
# 27569  31.18469063  10室3厅3卫  121.3578945
# 40074    23.148205  11室3厅3卫    113.34458
# 47757    23.116649  10室0厅1卫   113.287241
# 47760    23.116649  10室1厅1卫   113.287241
# 51608    23.008658  15室1厅1卫   113.310885
# 51748     23.00137  10室2厅2卫   113.341481
# 51893     23.00137  12室3厅3卫   113.341481
# 72856    22.552028  10室4厅5卫   113.971143
# 76503    22.552769  11室1厅4卫   113.903544
#
#                                                    m_url rent_area  \
# 17627  https://m.lianjia.com/chuzu/sh/zufang/SH226204...       450
# 17748  https://m.lianjia.com/chuzu/sh/zufang/SH223760...       568
# 18218  https://m.lianjia.com/chuzu/sh/zufang/SH224626...       638
# 20243  https://m.lianjia.com/chuzu/sh/zufang/SH212387...       581
# 23845  https://m.lianjia.com/chuzu/sh/zufang/SH226792...      5600
# 27569  https://m.lianjia.com/chuzu/sh/zufang/SH226788...      1000
# 40074  https://m.lianjia.com/chuzu/gz/zufang/GZ224208...       304
# 47757  https://m.lianjia.com/chuzu/gz/zufang/GZ222226...       480
# 47760  https://m.lianjia.com/chuzu/gz/zufang/GZ222227...       450
# 51608  https://m.lianjia.com/chuzu/gz/zufang/GZ213259...       408
# 51748  https://m.lianjia.com/chuzu/gz/zufang/GZ228522...       346
# 51893  https://m.lianjia.com/chuzu/gz/zufang/GZ228455...       198
# 72856  https://m.lianjia.com/chuzu/sz/zufang/SZ228457...       374
# 76503  https://m.lianjia.com/chuzu/sz/zufang/SZ226669...       263
#
#       rent_price_listing rent_price_unit resblock_name type
# 17627              85000             元/月        金庭庄园酒店   整租
# 17748             180000             元/月          大境别墅   整租
# 18218             250000             元/月      定西路1235弄   整租
# 20243             330000             元/月      花木路1701号   整租
# 23845             369600             元/月         汇洋北宿舍   整租
# 27569              42000             元/月          沪光小区   整租
# 40074              18000             元/月         协和新世界   整租
# 47757              33600             元/月          滨江中路   整租
# 47760              33000             元/月          滨江中路   整租
# 51608              25000             元/月        敏捷御峰国际   整租
# 51748              48500             元/月         保利大都汇   整租
# 51893              27500             元/月         保利大都汇   整租
# 72856             100000             元/月       名商高尔夫球会   整租
# 76503              40000             元/月       金泓凯旋城二期   整租

# %%
# 4. distance
data['frame_orientation'].unique()  # 这个数据太乱了，要用的时候再处理吧
# Out:
# array(['南', '东南', '南 北', '东 南 北', '东 北', '东', '西南', '西北', '东南 南', '西',
#        '北', '东 西', '南 西北', '东北', '东 南 西', '南 西 北', '东 东南', '东 东南 南',
#        '东南 西南', '南 西', '东南 北', '东 南', '东 南 西 北', '东 西北', '东 东北', '西 北',
#        '西南 北', '东 西 北', '南 西南 北', '北 东北', '东南 西', '南 西 西北', '西 西北',
#        '东南 东北', '西南 西北', '南 东北', '东南 南 北', '西南 西', '南 西南', '东南 西北',
#        '东 北 东北', '东 东南 南 西', '西南 东北', '东 西南', '南 北 东北', '南 西南 西',
#        '西南 西 西北', '东 东南 南 北', '', '西 西北 北', '西北 北', '东南 西南 西', '南 西北 北',
#        '东南 南 西', '西 东北', '东南 南 西南', '东 东南 南 西南 西', '东 东南 南 西南', '东南 南 西北',
#        ' 东南', '西北 东北', '未知', ' 东南 南', ' 南', ' 北', '东南 西南 西北',
#        ' 东 东南 南 西南 西 西北 北 东北', '东 东南 南 西南 西 西北 北 东北', ' 东 南', ' 西', ' 东',
#        '东 南 东北', '东 南 西南', '东 南 西南 西北', '东南 南 西南 西 西北 北', '东 东南 南 西南 西 北',
#        ' 东北', '东南 南 西北 北', '东 东南 南 西南 西北 北', '东 东南 南 西南 西 西北 北',
#        '东 东南 南 西南 北', ' 东南 北', '东南 南 西南 东北', '东 南 西南 西', '东 东南 西南 西',
#        '东 东南 南 西南 西 西北 东北', '西南 西北 北', '南 西南 东北', '东南 南 西南 北', ' 南 北',
#        '南 西南 西北', '东 东南 南 东北', '东南 西北 北', '东 南 西 西北', '东 东南 南 西 西北',
#        '南 西南 西 西北', ' 东 西南', '南 西南 西北 北', '东南 南 北 东北', '东南 南 西南 西',
#        '东 东南 南 西北 北', '东南 南 西南 西 西北', ' 西北', ' 西南', ' 西南 西北', '东 东南 西南',
#        '东 东南 南 西 北', '东南 南 西南 西 北', '东南 西南 西北 东北', '东 东南 西南 北',
#        '东 东南 西南 西 北', '西北 北 东北', '东南 南 东北', '东南 南 西 北', '东南 西北 东北',
#        '东南 西南 北', ' 东南 西南', '东 南 西北 东北', '东 南 西北', '东 东南 北',
#        '东 西 西北 北 东北', '东 东南 南 西北', '东 东南 南 西南 西 西北', '东 东南 西南 西北 东北',
#        '东南 南 西南 北 东北', '东 南 西南 西 西北 北', '西南 西 北', '西 北 东北', ' 西北 东北',
#        '东 东南 南 西南 东北', '东 东南 西北', '东 西 东北', '东南 西南 东北', '东南 南 西南 西北',
#        '东南 西 西北', '东 东南 西 东北', '东 西南 西北', '东 东南 西南 西北', '东 东南 西南 西 西北 北',
#        '东 东南 南 西南 北 东北', '东 东南 东北', '东 西南 西 西北', '西南 西北 东北', '南 西南 西 北',
#        '西南 西北 北 东北', '东 东南 北 东北', '东南 西南 西 西北 北 东北', '东 西南 西',
#        '东 东南 南 西南 西北', '东 东南 西', '东 西南 东北', '东南 西南 西北 北', '东南 南 西 西北 北',
#        '东 东南 西南 西 西北', ' 东南 南 西南 北', ' 东 东南', ' 东南 西北', '南 西南 西北 北 东北',
#        ' 东南 西', ' 东南 东北', '东南 西南 西 西北 东北', '东 东南 西 西北', '东 西 西北 北',
#        ' 东 东南 西北', '东 南 西南 北', '南 西 西北 北', '东南 南 西南 西北 北',
#        '东 东南 南 西 北 东北'], dtype=object)

# %%
# 5. hall_num
data['hall_num'].unique()
# Out:
# array(['2', '1', '0', '4', '3', '5', '7', '9', '6'], dtype=object)

# %%
data[data['hall_num'].isin(['6','11'])]
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 27427            6           7             华漕   上海   闵行      917
# 33518            8           8             赵巷   上海   青浦     None
# 33734            6           6            朱家角   上海   青浦      699
# 55926            5           1            星河湾   广州   番禺     None
# 76500            3           6           宝安中心   深圳  宝安区      451
#
#       frame_orientation hall_num house_tag        house_title  \
# 27427                 南        6      None        西郊庄园 7室6厅 南
# 33518                          6      None        整租·香水湾 8室6厅
# 33734                 南        6       近地铁      古北香堤艺墅 6室6厅 南
# 55926               南 北        6   新上 随时看房  广州星河湾朗心园 1室6厅 南/北
# 76500                 南        6       近地铁      天健时尚空间 6室6厅 南
#
#               latitude  layout        longitude  \
# 27427        31.203287  7室6厅6卫       121.290494
# 33518        31.158286  8室6厅8卫       121.248358
# 33734        31.115688  6室6厅6卫       121.048724
# 55926        23.033043  1室6厅5卫       113.337867
# 76500  22.555842332273  6室6厅3卫  113.89582360272
#
#                                                    m_url rent_area  \
# 27427  https://m.lianjia.com/chuzu/sh/zufang/SH225863...       573
# 33518  https://m.lianjia.com/chuzu/sh/zufang/SH192424...       498
# 33734  https://m.lianjia.com/chuzu/sh/zufang/SH221518...       285
# 55926  https://m.lianjia.com/chuzu/gz/zufang/GZ228903...       361
# 76500  https://m.lianjia.com/chuzu/sz/zufang/SZ223664...       270
#
#       rent_price_listing rent_price_unit resblock_name type
# 27427              80000             元/月          西郊庄园   整租
# 33518              30000             元/月           香水湾   整租
# 33734              25000             元/月        古北香堤艺墅   整租
# 55926              15800             元/月      广州星河湾朗心园   整租
# 76500              28000             元/月        天健时尚空间   整租

# %%
# 59223行是异常数据，删去
#data = data.drop([59223])

# %%
# 6. rent_area
data.sample(5)['rent_area']
# Out:
# 46018     65
# 37896    130
# 33823     20
# 79252     18
# 11871     72
# Name: rent_area, dtype: object

# %%
# rent_area字段有些填写的是一个范围，比如23-25平房米，后期转换成“float”类型的时候不好转换，考虑取平均值
def get_aver(data):
    if isinstance(data, str) and '-' in data:
        low, high = data.split('-')
        return (int(low)+int(high))/2
    else:
        return int(data)


data['rent_area'] = data['rent_area'].apply(get_aver)

# %%
data[data['rent_area'] < 5]
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 43425            1           2            东山口   广州   越秀       49
#
#       frame_orientation hall_num house_tag     house_title   latitude  layout  \
# 43425                 南        1    近地铁 新上  署前路署前二街 2室1厅 南  23.129259  2室1厅1卫
#
#         longitude                                              m_url  \
# 43425  113.300931  https://m.lianjia.com/chuzu/gz/zufang/GZ228976...
#
#        rent_area rent_price_listing rent_price_unit resblock_name type
# 43425        2.0               3900             元/月       署前路署前二街   整租

# %%
# 房间只有5平米，是异常数据，删去
data = data.drop(data[data['rent_area'] < 5].index)

# %%
# 7. rent_price_unit
data['rent_price_unit'].unique()
# Out:
# array(['元/月'], dtype=object)

# %%
# 租金都是以“元/月”计算的，所以这一列没用了，可以删了
data = data.drop(columns='rent_price_unit')

# %%
# 8. rent_price_listing
data[data['rent_price_listing'].str.contains('-')].sample(3)##.str.contains('-')
# Out:
#       bathroom_num bedroom_num bizcircle_name city dist distance  \
# 72994            1           1            科技园   深圳  南山区     None
# 45064            1           1            三元里   广州   白云     None
# 71871            1           1             新洲   深圳  福田区     None
#
#       frame_orientation hall_num                       house_tag  \
# 72994               南 北        0                独栋公寓 月租 近地铁 开放厨房
# 45064              东南 南        0                    独栋公寓 月租 开放厨房
# 71871                东南        1  独栋公寓 月租 拎包入住 近地铁 有阳台 开放厨房 押一付一
#
#                           house_title   latitude  layout   longitude  \
# 72994  独栋·YOU+优家青年创业社区 大学城社区 治愈系平层 开间  22.585749  1室0厅1卫  113.967499
# 45064      独栋·碧家国际社区 远景路店 C栋 精装一居室 开间  23.177569  1室0厅1卫  113.256014
# 71871       独栋·深圳优品公寓 新洲店 精装一房一厅 1室1厅  22.530116  1室1厅1卫  114.055053
#
#                                                    m_url  rent_area  \
# 72994  https://m.lianjia.com/chuzu/sz/apartment/layou...       13.5
# 45064  https://m.lianjia.com/chuzu/gz/apartment/layou...       32.0
# 71871  https://m.lianjia.com/chuzu/sz/apartment/layou...       42.0
#
#       rent_price_listing resblock_name type
# 72994          2225-2290                 整租
# 45064          2150-2190                 整租
# 71871          4300-4500                 整租

# %%
# 价格是有区间的，需要按照处理rent_area一样的方法处理
data['rent_price_listing'] = data['rent_price_listing'].apply(get_aver)##.apply

# %%
# 数据类型转换
for col in ['bathroom_num', 'bedroom_num', 'hall_num', 'rent_price_listing']:
    data[col] = data[col].astype(int)

# %%
# 'distance', 'latitude', 'longitude'因为有None，需另外处理
def dw_None_dis(data):
    if data is None:
        return np.nan
    else:
        return int(data)
    

def dw_None_latlon(data):
    if data is None or data == '':
        return np.nan
    else:
        return float(data)            


data['distance'] = data['distance'].apply(dw_None_dis)
data['latitude'] = data['latitude'].apply(dw_None_latlon)
data['longitude'] = data['longitude'].apply(dw_None_latlon)

# %%
# 查看数据概况
data.sample(5)
# Out:
#        bathroom_num  bedroom_num bizcircle_name city dist  distance  \
# 48092             1            1            滨江东   广州   海珠     747.0
# 52202             2            3            莲花山   广州   番禺       NaN
# 24850             1            3             罗泾   上海   宝山       NaN
# 89001             4            5           福田中心   深圳  福田区      78.0
# 79446             1            1             西乡   深圳  宝安区       NaN
#
#       frame_orientation  hall_num                  house_tag  \
# 48092                西南         1                        近地铁
# 52202                 南         2                       None
# 24850                 南         2                         新上
# 89001                 南         1  独立卫生间 月租 近地铁 精装 独立阳台 随时看房
# 79446                 东         0           独栋公寓 月租 拎包入住 近地铁
#
#                  house_title   latitude  layout   longitude  \
# 48092           听涛雅苑 1室1厅 西南  23.108003  1室1厅1卫  113.313225
# 52202          凯德山海连城 3室2厅 南  23.024965  3室2厅2卫  113.516749
# 24850           旭辉澜悦湾 3室2厅 南  31.471010  3室2厅1卫  121.355301
# 89001         合租·彩虹新都 5居室 南卧  22.541689  5室1厅4卫  114.075074
# 79446  独栋·平台认证机构 固戍店 雅居单间 开间  22.605819  1室0厅1卫  113.848346
#
#                                                    m_url  rent_area  \
# 48092  https://m.lianjia.com/chuzu/gz/zufang/GZ221581...       43.0
# 52202  https://m.lianjia.com/chuzu/gz/zufang/GZ219974...      124.0
# 24850  https://m.lianjia.com/chuzu/sh/zufang/SH228753...       89.0
# 89001  https://m.lianjia.com/chuzu/sz/zufang/SZ215908...       22.0
# 79446  https://m.lianjia.com/chuzu/sz/apartment/layou...       22.0
#
#        rent_price_listing resblock_name type
# 48092                3900          听涛雅苑   整租
# 52202                2500        凯德山海连城   整租
# 24850                3500         旭辉澜悦湾   整租
# 89001                3400          彩虹新都   合租
# 79446                1780                 整租

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92603 entries, 0 to 92603
# Data columns (total 18 columns):
# bathroom_num          92603 non-null int32
# bedroom_num           92603 non-null int32
# bizcircle_name        92603 non-null object
# city                  92603 non-null object
# dist                  92603 non-null object
# distance              48997 non-null float64
# frame_orientation     92603 non-null object
# hall_num              92603 non-null int32
# house_tag             73132 non-null object
# house_title           92603 non-null object
# latitude              92603 non-null float64
# layout                92603 non-null object
# longitude             92603 non-null float64
# m_url                 92603 non-null object
# rent_area             92603 non-null float64
# rent_price_listing    92603 non-null int32
# resblock_name         92603 non-null object
# type                  92603 non-null object
# dtypes: float64(4), int32(4), object(10)
# memory usage: 12.0+ MB

# %%
data.to_csv('data_clean.csv', index=False)

# %% [markdown]
# 问题：
# 1. 各城市的租房分布怎么样？
# 2. 城市各区域的房价分布怎么样？
# 2. 距离地铁口远近有什么关系？
# 3. 房屋大小对价格的影响如何？
# 4. 租个人房源好还是公寓好？
# 5. 精装和简装对房子价格的影响
# 6. 北方集中供暖对价格的影响
# 7. 北上广深租房时都看重什么？

# %% [markdown]
# ### 1. 各城市的租房分布怎么样？

# %%
def get_city_zf_loc(city, city_short, col=['longitude', 'latitude', 'dist'], data=data):
    file_name = 'data_' + city_short + '_latlon.csv'
    data_latlon = data.loc[data['city']==city, col].dropna(subset=['latitude', 'longitude'])
    data_latlon['longitude'] = data_latlon['longitude'].astype(str)#存放经度
    data_latlon['latitude'] = data_latlon['latitude'].astype(str)#存放维度
    data_latlon['latlon'] = data_latlon['longitude'].str.cat(data_latlon['latitude'], sep=',')#经纬度
    data_latlon.to_csv(file_name, index=False)#导出到Excel
    print(city+'的数据一共有{}条'.format(data_latlon.shape[0]))#打印数据长度

# %%
get_city_zf_loc('北京', 'bj', ['longitude','latitude', 'dist'])
get_city_zf_loc('上海', 'sh', ['longitude','latitude', 'dist'])
get_city_zf_loc('广州', 'gz', ['longitude','latitude', 'dist'])
get_city_zf_loc('深圳', 'sz', ['longitude','latitude', 'dist'])
# Out:
# 北京的数据一共有13690条
# 上海的数据一共有20113条
# 广州的数据一共有36045条
# 深圳的数据一共有22755条

# %%
fig = plt.figure(dpi=300)
#取出北京的数据，按dist出条形图
data.dropna(subset=['latitude', 'longitude'])[data['city']=='北京']['dist'].value_counts(ascending=True).plot.barh()

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='上海']['dist'].value_counts(ascending=True).plot.barh()

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='广州']['dist'].value_counts(ascending=True).plot.barh()

# %%
fig = plt.figure(dpi=300)
data.dropna(subset=['latitude', 'longitude'])[data['city']=='深圳']['dist'].value_counts(ascending=True).plot.barh()

# %% [markdown]
# ### 2. 城市各区域的房价分布怎么样？

# %%
data['aver_price'] = np.round(data['rent_price_listing'] / data['rent_area'], 1)#每平方租金
data.head()
# Out:
#    bathroom_num  bedroom_num bizcircle_name city dist  distance  \
# 0             2            3            世纪城   北京   海淀     721.0
# 1             2            3            世纪城   北京   海淀     828.0
# 2             1            2            世纪城   北京   海淀     724.0
# 3             2            3            世纪城   北京   海淀    1101.0
# 4             2            3            世纪城   北京   海淀     873.0
#
#   frame_orientation  hall_num             house_tag        house_title  \
# 0                 南         2           近地铁 集中供暖 新上         垂虹园 3室2厅 南
# 1                东南         2       精装 集中供暖 双卫生间 新上   整租·远大园五区 3室2厅 东南
# 2                东南         1         近地铁 集中供暖 随时看房      远大园四区 2室1厅 东南
# 3               南 北         2  精装 集中供暖 双卫生间 新上 随时看房  整租·远大园一区 3室2厅 南/北
# 4             东 南 北         2           近地铁 集中供暖 新上     春荫园 3室2厅 东/南/北
#
#     latitude  layout   longitude  \
# 0  39.967021  3室2厅2卫  116.293479
# 1  39.959175  3室2厅2卫  116.289427
# 2  39.959747  2室1厅1卫  116.292721
# 3  39.961689  3室2厅2卫  116.285995
# 4  39.968979  3室2厅2卫  116.288287
#
#                                                m_url  rent_area  \
# 0  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...      164.0
# 1  https://m.lianjia.com/chuzu/bj/zufang/BJ228955...      152.0
# 2  https://m.lianjia.com/chuzu/bj/zufang/BJ228178...       85.0
# 3  https://m.lianjia.com/chuzu/bj/zufang/BJ228759...      165.0
# 4  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...      162.0
#
#    rent_price_listing resblock_name type  aver_price
# 0               21000           垂虹园   整租       128.0
# 1               18000         远大园五区   整租       118.4
# 2                8500         远大园四区   整租       100.0
# 3               18000         远大园一区   整租       109.1
# 4               18000           春荫园   整租       111.1

# %%
g = sns.FacetGrid(data, row="city", height=4, aspect=2)#按city分别画频率的折线图
g = g.map(sns.kdeplot, "aver_price")#横坐标是aver_price

# %%
# 由于平均租金基本上都集中在250元/平米/月以内，所以选取这部分数据绘制热力图
def get_city_zf_aver_price(city, city_short, col=['longitude', 'latitude', 'aver_price'], data=data):
    file_name = 'data_' + city_short + '_aver_price.csv'
    data_latlon = data.loc[(data['city']==city)&(data['aver_price']<=250), col].dropna(subset=['latitude', 'longitude'])
    data_latlon['longitude'] = data_latlon['longitude'].astype(str)
    data_latlon['latitude'] = data_latlon['latitude'].astype(str)
    data_latlon['latlon'] = data_latlon['longitude'].str.cat(data_latlon['latitude'], sep=',')
    #data_latlon.to_csv(file_name, index=False)
    print(city+'的数据一共有{}条'.format(data_latlon.shape[0]))

# %%
get_city_zf_aver_price('北京', 'bj')
get_city_zf_aver_price('上海', 'sh')
get_city_zf_aver_price('广州', 'gz')
get_city_zf_aver_price('深圳', 'sz')
# Out:
# 北京的数据一共有13637条
# 上海的数据一共有19876条
# 广州的数据一共有35793条
# 深圳的数据一共有21914条

# %%
# 各城市租金Top10的商圈#按城市和商圈分组算aver_price的平均值，再取出前50的商圈，算它们在各城市的分布
bc_top10 = data.groupby(['city', 'bizcircle_name'])['aver_price'].mean().nlargest(50).reset_index()['city'].value_counts()
lab=[str(i) for i in bc_top10.index]
val=[int(i) for i in bc_top10.values]

# %%
# from pyecharts import Bar
# bar = Bar("每平米平均租金前50的北上广深商圈数量", width=400)
# bar.add("", bc_top10.index, bc_top10.values, is_stack=True,
#        xaxis_label_textsize=16, yaxis_label_textsize=16, is_label_show=True)
from pyecharts.charts import Bar
bar=Bar()
bar.add_xaxis(lab)
bar.add_yaxis("",val)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="7cd3f9d315264ccc842d2ff2629271d9" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_7cd3f9d315264ccc842d2ff2629271d9 = echarts.init(
#             document.getElementById('7cd3f9d315264ccc842d2ff2629271d9'), 'white', {renderer: 'canvas'});
#         var option_7cd3f9d315264ccc842d2ff2629271d9 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 25,
#                 16,
#                 9
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6df1\u5733",
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_7cd3f9d315264ccc842d2ff2629271d9.setOption(option_7cd3f9d315264ccc842d2ff2629271d9);
#     });
# </script>

# %%
def get_top10_bc(city, data=data):
    #取出城市为city,商圈不为空的数据，并按商圈计算aver_price的均值，取出前10个
    top10_bc = data[(data['city']==city)&(data['bizcircle_name']!='')].groupby('bizcircle_name')['aver_price'].mean().nlargest(10)
    #bar = Bar(city+"市每平米平均租金Top10的商圈", width=600)
    #bar.add("", top10_bc.index, np.round(top10_bc.values, 0), is_stack=True,
    #   xaxis_label_textsize=16, yaxis_label_textsize=16, xaxis_rotate=30, is_label_show=True)
    lab=[str(i) for i in top10_bc.index]
    value=[int(i) for i in top10_bc.values]
    bar=Bar()
    bar.add_xaxis(lab)
    bar.add_yaxis("",value)
    return bar.render_notebook()

# %%
# 北京每平米平均租金Top10的商圈
get_top10_bc('北京')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="b0d0f0f9905a475a957876eda153a6d8" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_b0d0f0f9905a475a957876eda153a6d8 = echarts.init(
#             document.getElementById('b0d0f0f9905a475a957876eda153a6d8'), 'white', {renderer: 'canvas'});
#         var option_b0d0f0f9905a475a957876eda153a6d8 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 160,
#                 160,
#                 158,
#                 157,
#                 156,
#                 150,
#                 150,
#                 148,
#                 147,
#                 141
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5706\u660e\u56ed",
#                 "\u77e5\u6625\u8def",
#                 "\u9b4f\u516c\u6751",
#                 "\u4e94\u9053\u53e3",
#                 "\u4e2d\u5173\u6751",
#                 "\u897f\u76f4\u95e8",
#                 "\u53cc\u6986\u6811",
#                 "\u4e07\u67f3",
#                 "\u56db\u5b63\u9752",
#                 "\u7682\u541b\u5e99"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_b0d0f0f9905a475a957876eda153a6d8.setOption(option_b0d0f0f9905a475a957876eda153a6d8);
#     });
# </script>

# %%
get_top10_bc('上海')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4a47946f8daf4492b714c0eb645882c1" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4a47946f8daf4492b714c0eb645882c1 = echarts.init(
#             document.getElementById('4a47946f8daf4492b714c0eb645882c1'), 'white', {renderer: 'canvas'});
#         var option_4a47946f8daf4492b714c0eb645882c1 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 222,
#                 212,
#                 201,
#                 197,
#                 181,
#                 179,
#                 177,
#                 169,
#                 168,
#                 164
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u65b0\u5929\u5730",
#                 "\u8861\u5c71\u8def",
#                 "\u6dee\u6d77\u4e2d\u8def",
#                 "\u95f8\u5317\u516c\u56ed",
#                 "\u9759\u5b89\u5bfa",
#                 "\u897f\u85cf\u5317\u8def",
#                 "\u5efa\u56fd\u897f\u8def",
#                 "\u5f90\u6c47\u6ee8\u6c5f",
#                 "\u5357\u4eac\u897f\u8def",
#                 "\u9ec4\u6d66\u6ee8\u6c5f"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_4a47946f8daf4492b714c0eb645882c1.setOption(option_4a47946f8daf4492b714c0eb645882c1);
#     });
# </script>

# %%
get_top10_bc('广州')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="2b93a5c4b03647f880f0b7d25e83c082" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_2b93a5c4b03647f880f0b7d25e83c082 = echarts.init(
#             document.getElementById('2b93a5c4b03647f880f0b7d25e83c082'), 'white', {renderer: 'canvas'});
#         var option_2b93a5c4b03647f880f0b7d25e83c082 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 142,
#                 141,
#                 135,
#                 134,
#                 129,
#                 123,
#                 120,
#                 118,
#                 108,
#                 108
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u9ec4\u6c99",
#                 "\u5929\u6cb3\u5357",
#                 "\u4eba\u6c11\u5317",
#                 "\u73e0\u6c5f\u65b0\u57ce\u4e2d",
#                 "\u4e8c\u6c99\u5c9b",
#                 "\u73e0\u6c5f\u65b0\u57ce\u897f",
#                 "\u73e0\u6c5f\u65b0\u57ce\u4e1c",
#                 "\u6587\u51b2",
#                 "\u5e7f\u5dde\u5927\u9053\u5357",
#                 "\u6797\u548c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_2b93a5c4b03647f880f0b7d25e83c082.setOption(option_2b93a5c4b03647f880f0b7d25e83c082);
#     });
# </script>

# %%
get_top10_bc('深圳')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="88e8ba2e2ec64d6d9b67fdbbc6d83de2" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_88e8ba2e2ec64d6d9b67fdbbc6d83de2 = echarts.init(
#             document.getElementById('88e8ba2e2ec64d6d9b67fdbbc6d83de2'), 'white', {renderer: 'canvas'});
#         var option_88e8ba2e2ec64d6d9b67fdbbc6d83de2 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 189,
#                 169,
#                 166,
#                 166,
#                 165,
#                 164,
#                 164,
#                 162,
#                 162,
#                 159
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6df1\u5733\u6e7e",
#                 "\u9999\u871c\u6e56",
#                 "\u798f\u7530\u4e2d\u5fc3",
#                 "\u7af9\u5b50\u6797",
#                 "\u9999\u6885\u5317",
#                 "\u9ec4\u6728\u5c97",
#                 "\u7ea2\u6811\u6e7e",
#                 "\u666f\u7530",
#                 "\u83b2\u82b1",
#                 "\u8f66\u516c\u5e99"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_88e8ba2e2ec64d6d9b67fdbbc6d83de2.setOption(option_88e8ba2e2ec64d6d9b67fdbbc6d83de2);
#     });
# </script>

# %% [markdown]
# ### 3. 距离地铁口远近有什么关系？

# %%
from scipy import stats

# %%
def distance_price_relation(city, data=data):
    g = sns.jointplot(x="distance", #横坐标
                      y="aver_price", #纵坐标
                      #提取城市为city,aver_price<=350的数据，并按distance xxx?
                  data=data[(data['city']==city)&(data['aver_price']<=350)].dropna(subset=['distance']), 
                  kind="reg",#加回归线
                 stat_func=stats.pearsonr)
    g.fig.set_dpi(100)
    g.ax_joint.set_xlabel('最近地铁距离', fontweight='bold')#横坐标标签
    g.ax_joint.set_ylabel('每平米租金', fontweight='bold')#纵坐标标签
    return g

# %%
distance_price_relation('北京')
# Out:
# F:\Anaconda\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
distance_price_relation('上海')
# Out:
# F:\Anaconda\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
distance_price_relation('广州')
# Out:
# F:\Anaconda\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
distance_price_relation('深圳')
# Out:
# F:\Anaconda\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
bins = [100*i for i in range(13)]
data['bin'] = pd.cut(data.dropna(subset=['distance'])['distance'], bins)#按bins切割distance，作为1个新字段
data.head()
# Out:
#    bathroom_num  bedroom_num bizcircle_name city dist  distance  \
# 0             2            3            世纪城   北京   海淀     721.0
# 1             2            3            世纪城   北京   海淀     828.0
# 2             1            2            世纪城   北京   海淀     724.0
# 3             2            3            世纪城   北京   海淀    1101.0
# 4             2            3            世纪城   北京   海淀     873.0
#
#   frame_orientation  hall_num             house_tag        house_title  \
# 0                 南         2           近地铁 集中供暖 新上         垂虹园 3室2厅 南
# 1                东南         2       精装 集中供暖 双卫生间 新上   整租·远大园五区 3室2厅 东南
# 2                东南         1         近地铁 集中供暖 随时看房      远大园四区 2室1厅 东南
# 3               南 北         2  精装 集中供暖 双卫生间 新上 随时看房  整租·远大园一区 3室2厅 南/北
# 4             东 南 北         2           近地铁 集中供暖 新上     春荫园 3室2厅 东/南/北
#
#     latitude  layout   longitude  \
# 0  39.967021  3室2厅2卫  116.293479
# 1  39.959175  3室2厅2卫  116.289427
# 2  39.959747  2室1厅1卫  116.292721
# 3  39.961689  3室2厅2卫  116.285995
# 4  39.968979  3室2厅2卫  116.288287
#
#                                                m_url  rent_area  \
# 0  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...      164.0
# 1  https://m.lianjia.com/chuzu/bj/zufang/BJ228955...      152.0
# 2  https://m.lianjia.com/chuzu/bj/zufang/BJ228178...       85.0
# 3  https://m.lianjia.com/chuzu/bj/zufang/BJ228759...      165.0
# 4  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...      162.0
#
#    rent_price_listing resblock_name type  aver_price           bin
# 0               21000           垂虹园   整租       128.0    (700, 800]
# 1               18000         远大园五区   整租       118.4    (800, 900]
# 2                8500         远大园四区   整租       100.0    (700, 800]
# 3               18000         远大园一区   整租       109.1  (1100, 1200]
# 4               18000           春荫园   整租       111.1    (800, 900]

# %%
bin_bj = data[data['city']=='北京'].groupby('bin')['aver_price'].mean()#按bin计算均值
bin_sh = data[data['city']=='上海'].groupby('bin')['aver_price'].mean()
bin_gz = data[data['city']=='广州'].groupby('bin')['aver_price'].mean()
bin_sz = data[data['city']=='深圳'].groupby('bin')['aver_price'].mean()

# %%
# from pyecharts import Line
# line = Line("距离地铁远近跟每平米租金均价的关系")
# for city, bin_data in {'北京':bin_bj, '上海':bin_sh, '广州':bin_gz, '深圳':bin_sz}.items():
#     line.add(city, bin_data.index, bin_data.values,
#             legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#              xaxis_rotate=20, yaxis_min=8, legend_top=30)
# line
from pyecharts.charts import Line
line=Line()
line.add_xaxis([str(i) for i in bin_bj.index])
for city, bin_data in {'北京':bin_bj, '上海':bin_sh, '广州':bin_gz, '深圳':bin_sz}.items():
    line.add_yaxis(str(city),[int(i) for i in bin_data.values])
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="eadbfb6599044fa193661e59ce92df35" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_eadbfb6599044fa193661e59ce92df35 = echarts.init(
#             document.getElementById('eadbfb6599044fa193661e59ce92df35'), 'white', {renderer: 'canvas'});
#         var option_eadbfb6599044fa193661e59ce92df35 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5317\u4eac",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "(0, 100]",
#                     91
#                 ],
#                 [
#                     "(100, 200]",
#                     95
#                 ],
#                 [
#                     "(200, 300]",
#                     91
#                 ],
#                 [
#                     "(300, 400]",
#                     89
#                 ],
#                 [
#                     "(400, 500]",
#                     83
#                 ],
#                 [
#                     "(500, 600]",
#                     88
#                 ],
#                 [
#                     "(600, 700]",
#                     89
#                 ],
#                 [
#                     "(700, 800]",
#                     91
#                 ],
#                 [
#                     "(800, 900]",
#                     82
#                 ],
#                 [
#                     "(900, 1000]",
#                     84
#                 ],
#                 [
#                     "(1000, 1100]",
#                     79
#                 ],
#                 [
#                     "(1100, 1200]",
#                     80
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u4e0a\u6d77",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "(0, 100]",
#                     121
#                 ],
#                 [
#                     "(100, 200]",
#                     122
#                 ],
#                 [
#                     "(200, 300]",
#                     125
#                 ],
#                 [
#                     "(300, 400]",
#                     118
#                 ],
#                 [
#                     "(400, 500]",
#                     114
#                 ],
#                 [
#                     "(500, 600]",
#                     119
#                 ],
#                 [
#                     "(600, 700]",
#                     112
#                 ],
#                 [
#                     "(700, 800]",
#                     118
#                 ],
#                 [
#                     "(800, 900]",
#                     102
#                 ],
#                 [
#                     "(900, 1000]",
#                     96
#                 ],
#                 [
#                     "(1000, 1100]",
#                     88
#                 ],
#                 [
#                     "(1100, 1200]",
#                     80
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e7f\u5dde",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "(0, 100]",
#                     82
#                 ],
#                 [
#                     "(100, 200]",
#                     86
#                 ],
#                 [
#                     "(200, 300]",
#                     83
#                 ],
#                 [
#                     "(300, 400]",
#                     89
#                 ],
#                 [
#                     "(400, 500]",
#                     79
#                 ],
#                 [
#                     "(500, 600]",
#                     76
#                 ],
#                 [
#                     "(600, 700]",
#                     74
#                 ],
#                 [
#                     "(700, 800]",
#                     79
#                 ],
#                 [
#                     "(800, 900]",
#                     72
#                 ],
#                 [
#                     "(900, 1000]",
#                     61
#                 ],
#                 [
#                     "(1000, 1100]",
#                     64
#                 ],
#                 [
#                     "(1100, 1200]",
#                     59
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u6df1\u5733",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "(0, 100]",
#                     137
#                 ],
#                 [
#                     "(100, 200]",
#                     132
#                 ],
#                 [
#                     "(200, 300]",
#                     133
#                 ],
#                 [
#                     "(300, 400]",
#                     145
#                 ],
#                 [
#                     "(400, 500]",
#                     125
#                 ],
#                 [
#                     "(500, 600]",
#                     121
#                 ],
#                 [
#                     "(600, 700]",
#                     135
#                 ],
#                 [
#                     "(700, 800]",
#                     124
#                 ],
#                 [
#                     "(800, 900]",
#                     137
#                 ],
#                 [
#                     "(900, 1000]",
#                     124
#                 ],
#                 [
#                     "(1000, 1100]",
#                     97
#                 ],
#                 [
#                     "(1100, 1200]",
#                     106
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "t

# %%
134.6-117#?
# Out:
# 17.599999999999994

# %% [markdown]
# ### 4. 房屋大小对每平米租金的影响如何？

# %%
def area_price_relation(city, data=data):
    fig = plt.figure(dpi=100)
    g = sns.lineplot(x="rent_area",#横坐标轴
                     y="aver_price",#纵坐标轴
                     data=data[(data['city']==city)&(data['rent_area']<150)],#取出指定city且rent_area<150的数据
                     ci=None)
    g.set_xlabel('面积', fontweight='bold')
    g.set_ylabel('每平米均价', fontweight='bold')
    return g

# %%
area_price_relation('北京')

# %%
area_price_relation('上海')

# %%
area_price_relation('广州')

# %%
area_price_relation('深圳')

# %%
# 根据house_title和house_tag再造一个字段：is_dep，也就是“是否是公寓”
data['is_dep'] = (data['house_title'].str.contains('公寓') + data['house_tag'].str.contains('公寓')) > 0
data.head()
# Out:
#    bathroom_num  bedroom_num bizcircle_name city dist  distance  \
# 0             2            3            世纪城   北京   海淀     721.0
# 1             2            3            世纪城   北京   海淀     828.0
# 2             1            2            世纪城   北京   海淀     724.0
# 3             2            3            世纪城   北京   海淀    1101.0
# 4             2            3            世纪城   北京   海淀     873.0
#
#   frame_orientation  hall_num             house_tag        house_title  ...  \
# 0                 南         2           近地铁 集中供暖 新上         垂虹园 3室2厅 南  ...
# 1                东南         2       精装 集中供暖 双卫生间 新上   整租·远大园五区 3室2厅 东南  ...
# 2                东南         1         近地铁 集中供暖 随时看房      远大园四区 2室1厅 东南  ...
# 3               南 北         2  精装 集中供暖 双卫生间 新上 随时看房  整租·远大园一区 3室2厅 南/北  ...
# 4             东 南 北         2           近地铁 集中供暖 新上     春荫园 3室2厅 东/南/北  ...
#
#    layout   longitude                                              m_url  \
# 0  3室2厅2卫  116.293479  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...
# 1  3室2厅2卫  116.289427  https://m.lianjia.com/chuzu/bj/zufang/BJ228955...
# 2  2室1厅1卫  116.292721  https://m.lianjia.com/chuzu/bj/zufang/BJ228178...
# 3  3室2厅2卫  116.285995  https://m.lianjia.com/chuzu/bj/zufang/BJ228759...
# 4  3室2厅2卫  116.288287  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...
#
#   rent_area  rent_price_listing  resblock_name type aver_price           bin  \
# 0     164.0               21000            垂虹园   整租      128.0    (700, 800]
# 1     152.0               18000          远大园五区   整租      118.4    (800, 900]
# 2      85.0                8500          远大园四区   整租      100.0    (700, 800]
# 3     165.0               18000          远大园一区   整租      109.1  (1100, 1200]
# 4     162.0               18000            春荫园   整租      111.1    (800, 900]
#
#   is_dep
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 21 columns]

# %%
# 每个城市房源的公寓占比
for city in ['北京', '上海', '广州', '深圳']:
    print(city+'的公寓占总房源量比重为:{}%。'.format(
        np.round(data[data['city']==city]['is_dep'].mean()*100, 2)))
# Out:
# 北京的公寓占总房源量比重为:1.17%。
# 上海的公寓占总房源量比重为:7.5%。
# 广州的公寓占总房源量比重为:16.42%。
# 深圳的公寓占总房源量比重为:48.38%。

# %%
data[(data['city']=='广州')&
    (data['rent_area']>0)&
    (data['rent_area']<60)&
    (data['aver_price']>100)]['is_dep'].mean()#广州的租房面积在0~60之间，每平方米单价为100以上的房子中，公寓的占比
# Out:
# 0.7496309418364334

# %% [markdown]
# ### 5. 租个人房源好还是公寓好？

# %%
is_dep = data[(data['city'].isin(['广州','深圳']))&
             (data['is_dep']==1)].groupby('city')['aver_price'].mean()#计算广州、深圳的公寓的每平方米租金的平均值
not_dep = data[(data['city'].isin(['广州','深圳']))&
             (data['is_dep']==0)].groupby('city')['aver_price'].mean()#计算广州、深圳的非公寓的每平方米租金的平均值
print(is_dep)
print(not_dep)
# Out:
# city
# 广州    104.915056
# 深圳    115.625709
# Name: aver_price, dtype: float64
# city
# 广州     53.020984
# 深圳    103.529727
# Name: aver_price, dtype: float64

# %%
# bar = Bar("个人房源和公寓的每平米租金差别", width=600)
# bar.add("个人房源", not_dep.index, np.round(not_dep.values, 0), 
#         legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
# bar.add("公寓", is_dep.index, np.round(is_dep.values, 0),
#        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
# bar
bar=Bar()
bar.add_xaxis([str(i) for i in is_dep.index])
for place,price in {"公寓":is_dep,"个人房源":not_dep}.items():   
    bar.add_yaxis(place,[int(i) for i in price.values])
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="042534bca9364a5aa128d9540d396d0c" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_042534bca9364a5aa128d9540d396d0c = echarts.init(
#             document.getElementById('042534bca9364a5aa128d9540d396d0c'), 'white', {renderer: 'canvas'});
#         var option_042534bca9364a5aa128d9540d396d0c = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u516c\u5bd3",
#             "data": [
#                 104,
#                 115
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u4e2a\u4eba\u623f\u6e90",
#             "data": [
#                 53,
#                 103
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u516c\u5bd3",
#                 "\u4e2a\u4eba\u623f\u6e90"
#             ],
#             "selected": {
#                 "\u516c\u5bd3": true,
#                 "\u4e2a\u4eba\u623f\u6e90": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_042534bca9364a5aa128d9540d396d0c.setOption(option_042534bca9364a5aa128d9540d396d0c);
#     });
# </script>

# %% [markdown]
# ### 5. 精装和简装对房子价格的影响

# %%
data['decorated'] = data[data['house_tag'].notna()]['house_tag'].str.contains('精装')#建一个新的字段，判断是否精装
data.head()
# Out:
#    bathroom_num  bedroom_num bizcircle_name city dist  distance  \
# 0             2            3            世纪城   北京   海淀     721.0
# 1             2            3            世纪城   北京   海淀     828.0
# 2             1            2            世纪城   北京   海淀     724.0
# 3             2            3            世纪城   北京   海淀    1101.0
# 4             2            3            世纪城   北京   海淀     873.0
#
#   frame_orientation  hall_num             house_tag        house_title  ...  \
# 0                 南         2           近地铁 集中供暖 新上         垂虹园 3室2厅 南  ...
# 1                东南         2       精装 集中供暖 双卫生间 新上   整租·远大园五区 3室2厅 东南  ...
# 2                东南         1         近地铁 集中供暖 随时看房      远大园四区 2室1厅 东南  ...
# 3               南 北         2  精装 集中供暖 双卫生间 新上 随时看房  整租·远大园一区 3室2厅 南/北  ...
# 4             东 南 北         2           近地铁 集中供暖 新上     春荫园 3室2厅 东/南/北  ...
#
#     longitude                                              m_url  rent_area  \
# 0  116.293479  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...      164.0
# 1  116.289427  https://m.lianjia.com/chuzu/bj/zufang/BJ228955...      152.0
# 2  116.292721  https://m.lianjia.com/chuzu/bj/zufang/BJ228178...       85.0
# 3  116.285995  https://m.lianjia.com/chuzu/bj/zufang/BJ228759...      165.0
# 4  116.288287  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...      162.0
#
#   rent_price_listing  resblock_name  type aver_price           bin  is_dep  \
# 0              21000            垂虹园    整租      128.0    (700, 800]   False
# 1              18000          远大园五区    整租      118.4    (800, 900]   False
# 2               8500          远大园四区    整租      100.0    (700, 800]   False
# 3              18000          远大园一区    整租      109.1  (1100, 1200]   False
# 4              18000            春荫园    整租      111.1    (800, 900]   False
#
#   decorated
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
#
# [5 rows x 22 columns]

# %%
decorated = data[data['decorated']==1].groupby('city')['aver_price'].mean()#计算每个城市的精装的每平方米租金
decorated
# Out:
# city
# 上海    125.965469
# 北京     86.429333
# 广州     65.579268
# 深圳    114.764202
# Name: aver_price, dtype: float64

# %%
not_decorated = data[data['decorated']==0].groupby('city')['aver_price'].mean()#计算每个城市的非精装的每平方米租金
not_decorated
# Out:
# city
# 上海     97.582286
# 北京     73.526828
# 广州     70.906614
# 深圳    110.134114
# Name: aver_price, dtype: float64

# %%
# bar = Bar("各城市精装和简装的每平米租金差别", width=600)
# bar.add("精装(刷过墙)", decorated.index, np.round(decorated.values, 0), 
#         legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
# bar.add("简装(破房子)", not_decorated.index, np.round(not_decorated.values, 0),
#        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
# bar
bar=Bar()
bar.add_xaxis([str(i) for i in decorated.index])
bar.add_yaxis("精装(刷过墙)",[int(i) for i in decorated.values])
bar.add_yaxis("简装(破房子)",[int(i) for i in not_decorated.values])
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="5d8a4b5c069d4d1dbd49fb2b47d08c65" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_5d8a4b5c069d4d1dbd49fb2b47d08c65 = echarts.init(
#             document.getElementById('5d8a4b5c069d4d1dbd49fb2b47d08c65'), 'white', {renderer: 'canvas'});
#         var option_5d8a4b5c069d4d1dbd49fb2b47d08c65 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7cbe\u88c5(\u5237\u8fc7\u5899)",
#             "data": [
#                 125,
#                 86,
#                 65,
#                 114
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7b80\u88c5(\u7834\u623f\u5b50)",
#             "data": [
#                 97,
#                 73,
#                 70,
#                 110
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cbe\u88c5(\u5237\u8fc7\u5899)",
#                 "\u7b80\u88c5(\u7834\u623f\u5b50)"
#             ],
#             "selected": {
#                 "\u7cbe\u88c5(\u5237\u8fc7\u5899)": true,
#                 "\u7b80\u88c5(\u7834\u623f\u5b50)": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_5d8a4b5c069d4d1dbd49fb2b47d08c65.setOption(option_5d8a4b5c069d4d1dbd49fb2b47d08c65);
#     });
# </script>

# %%
#广州和深圳的精装且为公寓的平均每平方米租金
is_dec_dep = data[(data['decorated']==1)&
                  (data['is_dep']==1)&
                 (data['city'].isin(['广州', '深圳']))].groupby('city')['aver_price'].mean()
is_dec_dep
# Out:
# city
# 广州    124.448748
# 深圳    109.925319
# Name: aver_price, dtype: float64

# %%
#广州和深圳的精装且为非公寓的平均每平方米租金
is_dec_not_dep = data[(data['decorated']==1)&
                      (data['is_dep']==0)&
                     (data['city'].isin(['广州', '深圳']))].groupby('city')['aver_price'].mean()
is_dec_not_dep
# Out:
# city
# 广州     50.351695
# 深圳    119.116415
# Name: aver_price, dtype: float64

# %%
#广州和深圳的非精装且为非公寓的平均每平方米租金
not_dec_dep = data[(data['decorated']==0)&
                   (data['is_dep']==0)&
                  (data['city'].isin(['广州', '深圳']))].groupby('city')['aver_price'].mean()
not_dec_dep
# Out:
# city
# 广州     60.374146
# 深圳    102.049483
# Name: aver_price, dtype: float64

# %%
# bar = Bar("各城市装修和房源类型的每平米租金差别", width=600)
# bar.add("精装公寓", is_dec_dep.index, np.round(is_dec_dep.values, 0), 
#         legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
# bar.add("精装个人房源", is_dec_not_dep.index, np.round(is_dec_not_dep.values, 0),
#        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
# bar.add("简装个人房源", not_dec_dep.index, np.round(not_dec_dep.values, 0),
#        legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
# bar
bar=Bar()
bar.add_xaxis([str(i) for i in is_dec_dep.index])
bar.add_yaxis("精装公寓",[int(i) for i in is_dec_dep.values])
bar.add_yaxis("精装个人房源",[int(i) for i in is_dec_not_dep.values])
bar.add_yaxis("简装个人房源",[int(i) for i in not_dec_dep.values])
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="e5fd4770f13743fab0f0d7e49f33ffb3" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_e5fd4770f13743fab0f0d7e49f33ffb3 = echarts.init(
#             document.getElementById('e5fd4770f13743fab0f0d7e49f33ffb3'), 'white', {renderer: 'canvas'});
#         var option_e5fd4770f13743fab0f0d7e49f33ffb3 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7cbe\u88c5\u516c\u5bd3",
#             "data": [
#                 124,
#                 109
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7cbe\u88c5\u4e2a\u4eba\u623f\u6e90",
#             "data": [
#                 50,
#                 119
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7b80\u88c5\u4e2a\u4eba\u623f\u6e90",
#             "data": [
#                 60,
#                 102
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7cbe\u88c5\u516c\u5bd3",
#                 "\u7cbe\u88c5\u4e2a\u4eba\u623f\u6e90",
#                 "\u7b80\u88c5\u4e2a\u4eba\u623f\u6e90"
#             ],
#             "selected": {
#                 "\u7cbe\u88c5\u516c\u5bd3": true,
#                 "\u7cbe\u88c5\u4e2a\u4eba\u623f\u6e90": true,
#                 "\u7b80\u88c5\u4e2a\u4eba\u623f\u6e90": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_e5fd4770f13743fab0f0d7e49f33ffb3.setOption(option_e5fd4770f13743fab0f0d7e49f33ffb3);
#     });
# </script>

# %% [markdown]
# ### 7. 北方集中供暖对价格的影响

# %%
data['ct_heating'] = data['house_tag'].str.contains('集中供暖')#新建一个字段，判断是否含有集中供暖
data.head()
# Out:
#    bathroom_num  bedroom_num bizcircle_name city dist  distance  \
# 0             2            3            世纪城   北京   海淀     721.0
# 1             2            3            世纪城   北京   海淀     828.0
# 2             1            2            世纪城   北京   海淀     724.0
# 3             2            3            世纪城   北京   海淀    1101.0
# 4             2            3            世纪城   北京   海淀     873.0
#
#   frame_orientation  hall_num             house_tag        house_title  ...  \
# 0                 南         2           近地铁 集中供暖 新上         垂虹园 3室2厅 南  ...
# 1                东南         2       精装 集中供暖 双卫生间 新上   整租·远大园五区 3室2厅 东南  ...
# 2                东南         1         近地铁 集中供暖 随时看房      远大园四区 2室1厅 东南  ...
# 3               南 北         2  精装 集中供暖 双卫生间 新上 随时看房  整租·远大园一区 3室2厅 南/北  ...
# 4             东 南 北         2           近地铁 集中供暖 新上     春荫园 3室2厅 东/南/北  ...
#
#                                                m_url rent_area  \
# 0  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...     164.0
# 1  https://m.lianjia.com/chuzu/bj/zufang/BJ228955...     152.0
# 2  https://m.lianjia.com/chuzu/bj/zufang/BJ228178...      85.0
# 3  https://m.lianjia.com/chuzu/bj/zufang/BJ228759...     165.0
# 4  https://m.lianjia.com/chuzu/bj/zufang/BJ229062...     162.0
#
#    rent_price_listing resblock_name  type  aver_price           bin is_dep  \
# 0               21000           垂虹园    整租       128.0    (700, 800]  False
# 1               18000         远大园五区    整租       118.4    (800, 900]  False
# 2                8500         远大园四区    整租       100.0    (700, 800]  False
# 3               18000         远大园一区    整租       109.1  (1100, 1200]  False
# 4               18000           春荫园    整租       111.1    (800, 900]  False
#
#    decorated ct_heating
# 0      False       True
# 1       True       True
# 2      False       True
# 3       True       True
# 4      False       True
#
# [5 rows x 23 columns]

# %%
data[data['city']=='北京'].groupby('ct_heating')['aver_price'].mean()#北京的是否供暖的房子的平均每平方米租金
# Out:
# ct_heating
# False    77.841353
# True     76.536475
# Name: aver_price, dtype: float64

# %% [markdown]
# ### 8. 各城市房屋租售比

# %%
zs_ratio = [57036, 62779, 32039, 56758]/((data.groupby('city')['rent_price_listing'].sum()/data.groupby('city')['rent_area'].sum())*12)
zs_ratio#平均房价（买）与平均租金的比
# Out:
# city
# 上海    49.384111
# 北京    68.773261
# 广州    50.614848
# 深圳    47.063603
# dtype: float64

# %%
# bar = Bar("各城市房屋租售比(租多少年可以在该城市买下一套房)", width=450)
# bar.add("", zs_ratio.index, np.round(zs_ratio.values, 0), 
#         legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
#         xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
# bar
bar=Bar()
bar.add_xaxis([str(i) for i in zs_ratio.index])
bar.add_yaxis("",[int(i) for i in zs_ratio.values])
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="870c77da048447f18c90518373069b76" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_870c77da048447f18c90518373069b76 = echarts.init(
#             document.getElementById('870c77da048447f18c90518373069b76'), 'white', {renderer: 'canvas'});
#         var option_870c77da048447f18c90518373069b76 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 49,
#                 68,
#                 50,
#                 47
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u4e0a\u6d77",
#                 "\u5317\u4eac",
#                 "\u5e7f\u5dde",
#                 "\u6df1\u5733"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_870c77da048447f18c90518373069b76.setOption(option_870c77da048447f18c90518373069b76);
#     });
# </script>

# %% [markdown]
# ### 9. 北上广深租房时都看重什么？

# %%
def layout_top3(city, data):
    layout_data = data[data['city']==city]['layout'].value_counts().nlargest(3)#取出指定城市的最多的3个layout
    #bar = Bar(city+"最受欢迎的户型", width=600)
    #bar.add("", layout_data.index, layout_data.values, 
    #    legend_text_size=18,xaxis_label_textsize=14,yaxis_label_textsize=18,
    #    xaxis_rotate=20, yaxis_min=8, legend_top=30, is_label_show=True)
    #return bar
    bar=Bar()
    bar.add_xaxis([str(i) for i in layout_data.index])
    bar.add_yaxis("",[int(i) for i in layout_data.values])
    return bar.render_notebook()

# %%
layout_top3('北京', data)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="ade1d2cfdda24a188cd36bf4dfa90f1c" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_ade1d2cfdda24a188cd36bf4dfa90f1c = echarts.init(
#             document.getElementById('ade1d2cfdda24a188cd36bf4dfa90f1c'), 'white', {renderer: 'canvas'});
#         var option_ade1d2cfdda24a188cd36bf4dfa90f1c = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 5352,
#                 1632,
#                 1133
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2\u5ba41\u53851\u536b",
#                 "1\u5ba41\u53851\u536b",
#                 "3\u5ba41\u53851\u536b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_ade1d2cfdda24a188cd36bf4dfa90f1c.setOption(option_ade1d2cfdda24a188cd36bf4dfa90f1c);
#     });
# </script>

# %%
layout_top3('上海', data)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="e2c94a3df0584cdc97e9332aa5d11d67" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_e2c94a3df0584cdc97e9332aa5d11d67 = echarts.init(
#             document.getElementById('e2c94a3df0584cdc97e9332aa5d11d67'), 'white', {renderer: 'canvas'});
#         var option_e2c94a3df0584cdc97e9332aa5d11d67 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 3303,
#                 3241,
#                 2885
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2\u5ba41\u53851\u536b",
#                 "1\u5ba41\u53851\u536b",
#                 "3\u5ba42\u53852\u536b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_e2c94a3df0584cdc97e9332aa5d11d67.setOption(option_e2c94a3df0584cdc97e9332aa5d11d67);
#     });
# </script>

# %%
layout_top3('广州', data)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="ef89f1c548df4b06bc5298e7fc10a744" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_ef89f1c548df4b06bc5298e7fc10a744 = echarts.init(
#             document.getElementById('ef89f1c548df4b06bc5298e7fc10a744'), 'white', {renderer: 'canvas'});
#         var option_ef89f1c548df4b06bc5298e7fc10a744 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 6276,
#                 4856,
#                 4780
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2\u5ba41\u53851\u536b",
#                 "3\u5ba42\u53852\u536b",
#                 "1\u5ba41\u53851\u536b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_ef89f1c548df4b06bc5298e7fc10a744.setOption(option_ef89f1c548df4b06bc5298e7fc10a744);
#     });
# </script>

# %%
layout_top3('深圳', data)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="565fcdc2c2d248218a74d7dcfe44486f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_565fcdc2c2d248218a74d7dcfe44486f = echarts.init(
#             document.getElementById('565fcdc2c2d248218a74d7dcfe44486f'), 'white', {renderer: 'canvas'});
#         var option_565fcdc2c2d248218a74d7dcfe44486f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 4303,
#                 3729,
#                 2925
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1\u5ba40\u53851\u536b",
#                 "1\u5ba41\u53851\u536b",
#                 "2\u5ba41\u53851\u536b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_565fcdc2c2d248218a74d7dcfe44486f.setOption(option_565fcdc2c2d248218a74d7dcfe44486f);
#     });
# </script>

# %%
from pyecharts.charts import WordCloud
from collections import Counter

# %%
bj_tag = []
for st in data[data['city']=='北京'].dropna(subset=['house_tag'])['house_tag']:#取出北京的所有非空的house_tag
    bj_tag.extend(st.split(' '))#按空格切割存入一个list
freq=[(name,value) for name,value in Counter(bj_tag).items()]#计算每个元素的频数
print(freq)
# name, value = WordCloud.cast(Counter(bj_tag))
# wordcloud = WordCloud(width=500, height=500)
# wordcloud.add("", name, value, word_size_range=[20, 100])
wordcloud=WordCloud()
wordcloud.add("",freq)#按频数出词云
wordcloud.render_notebook()
# Out:
# [('近地铁', 5688), ('集中供暖', 10684), ('新上', 2672), ('精装', 3283), ('双卫生间', 1210), ('随时看房', 5821), ('押一付一', 5), ('月租', 18)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="9e1c40f5d1074191abb54c40be7f4ebb" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_9e1c40f5d1074191abb54c40be7f4ebb = echarts.init(
#             document.getElementById('9e1c40f5d1074191abb54c40be7f4ebb'), 'white', {renderer: 'canvas'});
#         var option_9e1c40f5d1074191abb54c40be7f4ebb = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u8fd1\u5730\u94c1",
#                     "value": 5688,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(18,116,30)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u96c6\u4e2d\u4f9b\u6696",
#                     "value": 10684,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,158,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u4e0a",
#                     "value": 2672,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(146,62,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 3283,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(104,101,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u536b\u751f\u95f4",
#                     "value": 1210,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,42,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u968f\u65f6\u770b\u623f",
#                     "value": 5821,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(86,68,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62bc\u4e00\u4ed8\u4e00",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(110,105,154)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u79df",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,118,133)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     }
# };
#         chart_9e1c40f5d1074191abb54c40be7f4ebb.setOption(option_9e1c40f5d1074191abb54c40be7f4ebb);
#     });
# </script>

# %%
sh_tag = []
for st in data[data['city']=='上海'].dropna(subset=['house_tag'])['house_tag']:
    sh_tag.extend(st.split(' '))

# name, value = WordCloud.cast(Counter(sh_tag))
# wordcloud = WordCloud(width=500, height=500)
# wordcloud.add("", name, value, word_size_range=[20, 100])
# wordcloud
freq=[(name,value) for name,value in Counter(sh_tag).items()]#计算每个元素的频数
print(freq)
wordcloud=WordCloud()
wordcloud.add("",freq)#按频数出词云
wordcloud.render_notebook()
# Out:
# [('近地铁', 10616), ('新上', 3676), ('精装', 4619), ('随时看房', 4078), ('双卫生间', 1699), ('押一付一', 146), ('月租', 11)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="d042cd5ca3ef41099e38875f527aa165" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_d042cd5ca3ef41099e38875f527aa165 = echarts.init(
#             document.getElementById('d042cd5ca3ef41099e38875f527aa165'), 'white', {renderer: 'canvas'});
#         var option_d042cd5ca3ef41099e38875f527aa165 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u8fd1\u5730\u94c1",
#                     "value": 10616,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,96,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u4e0a",
#                     "value": 3676,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(151,21,100)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 4619,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,119,45)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u968f\u65f6\u770b\u623f",
#                     "value": 4078,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,150,41)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u536b\u751f\u95f4",
#                     "value": 1699,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,146,104)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62bc\u4e00\u4ed8\u4e00",
#                     "value": 146,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(47,43,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u79df",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,116,117)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     }
# };
#         chart_d042cd5ca3ef41099e38875f527aa165.setOption(option_d042cd5ca3ef41099e38875f527aa165);
#     });
# </script>

# %%
gz_tag = []
for st in data[data['city']=='广州'].dropna(subset=['house_tag'])['house_tag']:
    gz_tag.extend(st.split(' '))

# name, value = WordCloud.cast(Counter(gz_tag))
# wordcloud = WordCloud(width=500, height=500)
# wordcloud.add("", name, value, word_size_range=[20, 100])
# wordcloud
freq=[(name,value) for name,value in Counter(gz_tag).items()]#计算每个元素的频数
print(freq)
wordcloud=WordCloud()
wordcloud.add("",freq)#按频数出词云
wordcloud.render_notebook()
# Out:
# [('随时看房', 7366), ('独栋公寓', 3245), ('月租', 3275), ('有阳台', 2078), ('开放厨房', 2069), ('押一付一', 2334), ('公寓', 2321), ('精装', 3304), ('新上', 4730), ('双卫生间', 1295), ('贝壳实勘', 130), ('近地铁', 15869), ('拎包入住', 620), ('独立卫生间', 178), ('独立阳台', 525), ('限女生', 38), ('限男生', 19)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="89e29f0daba241269aa2ffc5681b0bf8" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_89e29f0daba241269aa2ffc5681b0bf8 = echarts.init(
#             document.getElementById('89e29f0daba241269aa2ffc5681b0bf8'), 'white', {renderer: 'canvas'});
#         var option_89e29f0daba241269aa2ffc5681b0bf8 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u968f\u65f6\u770b\u623f",
#                     "value": 7366,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,108,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u680b\u516c\u5bd3",
#                     "value": 3245,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(135,109,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u79df",
#                     "value": 3275,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(11,62,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u9633\u53f0",
#                     "value": 2078,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,158,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f00\u653e\u53a8\u623f",
#                     "value": 2069,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,136,147)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62bc\u4e00\u4ed8\u4e00",
#                     "value": 2334,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(96,47,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5bd3",
#                     "value": 2321,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,40,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 3304,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,92,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u4e0a",
#                     "value": 4730,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(95,153,33)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u536b\u751f\u95f4",
#                     "value": 1295,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,34,88)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8d1d\u58f3\u5b9e\u52d8",
#                     "value": 130,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(79,115,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd1\u5730\u94c1",
#                     "value": 15869,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(26,38,28)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62ce\u5305\u5165\u4f4f",
#                     "value": 620,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,155,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7acb\u536b\u751f\u95f4",
#                     "value": 178,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,18,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7acb\u9633\u53f0",
#                     "value": 525,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,120,17)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9650\u5973\u751f",
#                     "value": 38,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(28,40,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9650\u7537\u751f",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(50,87,134)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     }
# };
#         chart_89e29f0daba241269aa2ffc5681b0bf8.setOption(option_89e29f0daba241269aa2ffc5681b0bf8);
#     });
# </script>

# %%
sz_tag = []
for st in data[data['city']=='深圳'].dropna(subset=['house_tag'])['house_tag']:
    sz_tag.extend(st.split(' '))

# name, value = WordCloud.cast(Counter(sz_tag))
# wordcloud = WordCloud(width=500, height=500)
# wordcloud.add("", name, value, word_size_range=[20, 100])
# wordcloud
freq=[(name,value) for name,value in Counter(sz_tag).items()]#计算每个元素的频数
print(freq)
wordcloud=WordCloud()
wordcloud.add("",freq)#按频数出词云
wordcloud.render_notebook()
# Out:
# [('近地铁', 15245), ('新上', 3407), ('随时看房', 11141), ('独栋公寓', 5267), ('开放厨房', 4001), ('公寓', 5443), ('月租', 6898), ('双卫生间', 1250), ('有阳台', 2563), ('押一付一', 2833), ('精装', 5288), ('拎包入住', 1699), ('独立阳台', 756), ('限女生', 17), ('限男生', 5), ('独立卫生间', 385)]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#     <div id="1d7534511a324e389627bd817ea70120" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'echarts-wordcloud'], function(echarts) {
#         var chart_1d7534511a324e389627bd817ea70120 = echarts.init(
#             document.getElementById('1d7534511a324e389627bd817ea70120'), 'white', {renderer: 'canvas'});
#         var option_1d7534511a324e389627bd817ea70120 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "\u8fd1\u5730\u94c1",
#                     "value": 15245,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(0,80,0)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65b0\u4e0a",
#                     "value": 3407,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(1,156,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u968f\u65f6\u770b\u623f",
#                     "value": 11141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(156,13,119)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u680b\u516c\u5bd3",
#                     "value": 5267,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,83,155)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5f00\u653e\u53a8\u623f",
#                     "value": 4001,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,106,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u516c\u5bd3",
#                     "value": 5443,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,12,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6708\u79df",
#                     "value": 6898,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,54,152)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53cc\u536b\u751f\u95f4",
#                     "value": 1250,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(84,39,151)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u9633\u53f0",
#                     "value": 2563,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,18,120)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62bc\u4e00\u4ed8\u4e00",
#                     "value": 2833,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(143,114,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7cbe\u88c5",
#                     "value": 5288,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,62,71)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u62ce\u5305\u5165\u4f4f",
#                     "value": 1699,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(136,97,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7acb\u9633\u53f0",
#                     "value": 756,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,34,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9650\u5973\u751f",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,43,160)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9650\u7537\u751f",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,34,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72ec\u7acb\u536b\u751f\u95f4",
#                     "value": 385,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,133,102)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     }
# };
#         chart_1d7534511a324e389627bd817ea70120.setOption(option_1d7534511a324e389627bd817ea70120);
#     });
# </script>

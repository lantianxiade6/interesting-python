# %% [markdown]
# https://github.com/Alfred1984/interesting-python/blob/master/English_names/Babynames.ipynb

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt#画图用
import seaborn as sns#设文字用
from pyecharts.charts import Bar, Line#打开cmd, pip install pyecharts,然后重启jupyter
#from pyecharts import Overlap#好像已经没有这个了

from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']  #解决seaborn中文字体显示问题
plt.rc('figure', figsize=(10, 10))  #把plt默认的图片size调大一点
#画布
# %matplotlib inline

# %%
data = pd.read_csv('NationalNames.csv')#自己先手动解压zip

# %%
data.head()#查看前6行数据
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746

# %%
data.info()#查看数据基本信息
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1924665 entries, 0 to 1924664
# Data columns (total 5 columns):
# Id        int64
# Name      object
# Year      int64
# Gender    object
# Count     int64
# dtypes: int64(3), object(2)
# memory usage: 73.4+ MB

# %% [markdown]
# ## 1. 2010-2017年，Top15的男生、女生英文名

# %% [markdown]
# ### - 男生

# %% [markdown]
# data.loc[xx,:]

# %%
#取出Year=2010-2017和Gender=M的行，并按Name汇总，并按Count求和，取出最大的15个
top15_boy = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'M'), :].groupby('Name').Count.sum().nlargest(15)
top15_boy
# Out:
# Name
# Noah         145195
# Jacob        140091
# Mason        133535
# Liam         133019
# William      131241
# Ethan        125561
# Michael      122265
# Alexander    118376
# James        112387
# Daniel       111658
# Elijah       110075
# Aiden        109852
# Jayden       109122
# Benjamin     107648
# Matthew      105429
# Name: Count, dtype: int64

# %%
boy_total = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'M'), :].groupby('Name').Count.sum().sum()
boy_total#同样条件算Count加总
# Out:
# 15140560

# %%
from wordcloud import WordCloud
name = list(top15_boy.index)#取出名字
value = list(top15_boy.values)#取出数量
frequency={key:val for key in name for val in value}#转成dict
wordcloud = WordCloud(width=800, height=450,background_color='#f2eada')  # feeeed #设定词云图参数
#wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')#加入名字和数量，形状为砖石 #貌似已经没有这个方法了
wordcloud.generate_from_frequencies(frequency)
wordcloud
plt.imshow(wordcloud)#画出图片

# %%
data_top15_boy = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'M') & 
                          (data['Name']).isin(list(top15_boy.index)), :]#取出规定Year=2010-2017和Gender=M下，且名字在top15_boy里面的数据

# %%
data_top15_boy.sort_values(by = ['Year', 'Count'], ascending=False, inplace=True)#按Year和count按升序排序
data_top15_boy.head()#查看前6行
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#               Id      Name  Year Gender  Count
# 1910505  1910506      Liam  2017      M  18728
# 1910506  1910507      Noah  2017      M  18326
# 1910507  1910508   William  2017      M  14904
# 1910508  1910509     James  2017      M  14232
# 1910510  1910511  Benjamin  2017      M  13733

# %%
sns.set(font_scale=1.4)#设置文字大小
g = sns.FacetGrid(data_top15_boy, col="Name", col_wrap=3)#设置每个Name一张图，每行3列
g = g.map(plt.plot, "Year", "Count",color="c",marker=".")#横坐标为Year，纵坐标为Count画15个图
#g.set(axis_bgcolor='#feeeed')#设置背景颜色 #f2eada  #不知道为什么会报错

# %% [markdown]
# ### - 女生

# %%
top15_girl = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'F'), :].groupby('Name').Count.sum().nlargest(15)
#同样条件女生版
top15_girl
# Out:
# Name
# Emma         158573
# Sophia       152936
# Olivia       147486
# Isabella     142064
# Ava          125937
# Mia          103580
# Emily        100414
# Abigail       99356
# Madison       84803
# Elizabeth     77233
# Charlotte     76031
# Chloe         71994
# Ella          69455
# Amelia        68291
# Avery         67348
# Name: Count, dtype: int64

# %%
list(data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'F'), :].groupby('Name').Count.sum().nlargest(30).index)
#前30的名字
# Out:
# ['Emma',
#  'Sophia',
#  'Olivia',
#  'Isabella',
#  'Ava',
#  'Mia',
#  'Emily',
#  'Abigail',
#  'Madison',
#  'Elizabeth',
#  'Charlotte',
#  'Chloe',
#  'Ella',
#  'Amelia',
#  'Avery',
#  'Sofia',
#  'Evelyn',
#  'Harper',
#  'Addison',
#  'Grace',
#  'Natalie',
#  'Victoria',
#  'Lily',
#  'Aubrey',
#  'Lillian',
#  'Zoey',
#  'Hannah',
#  'Brooklyn',
#  'Layla',
#  'Samantha']

# %%
name = list(top15_girl.index)#取出名字
value = list(top15_girl.values)#取出数据
frequency={key:val for key in name for val in value}#转成dict
wordcloud = WordCloud(width=800, height=500,background_color='#feeeed')  # feeeed
#wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
wordcloud.generate_from_frequencies(frequency)#化词云图
wordcloud
plt.imshow(wordcloud)#画出图片

# %%
data_top15_girl = data.loc[(data['Year'].isin(list(range(2010,2018)))) & (data['Gender'] == 'F') & 
                          (data['Name']).isin(list(top15_girl.index)), :]#取出数据

data_top15_girl.sort_values(by = ['Year', 'Count'], ascending=False, inplace=True)#按Year和Count排序

sns.set(font_scale=1.4)
g = sns.FacetGrid(data_top15_girl, col="Name", col_wrap=3)#每个名字画一张图

g = g.map(plt.plot, "Year", "Count",color="c",marker=".")
#g.set(axis_bgcolor='#feeeed')
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## 2. 每个年代，最流行的英文名字
# - 1920-2017

# %% [markdown]
# data[xxx]

# %%
data_decades = data[data['Year']>=1920]#取出1920及以后数据
data_decades['decade'] = pd.cut(data_decades['Year'], [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010,2018], 
                                labels = ['20后','30后','40后', '50后','60后','70后','80后','90后','00后','10后'],right=False)#对Year切割，得到年代
data_decades.head()
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#             Id      Name  Year Gender  Count decade
# 169455  169456      Mary  1920      F  70980    20后
# 169456  169457   Dorothy  1920      F  36643    20后
# 169457  169458     Helen  1920      F  35097    20后
# 169458  169459  Margaret  1920      F  27997    20后
# 169459  169460      Ruth  1920      F  26101    20后

# %%
decade = data_decades.groupby(['decade', 'Gender', 'Name']).Count.sum().groupby(level=[0,1]).nlargest(1)
#按decade、Gender、Name汇总，并取出每组Count总和最大的那个
decade.head()
# Out:
# decade  Gender  decade  Gender  Name
# 20后     F       20后     F       Mary      701746
#         M       20后     M       Robert    576362
# 30后     F       30后     F       Mary      572942
#         M       30后     M       Robert    590716
# 40后     F       40后     F       Mary      640023
# Name: Count, dtype: int64

# %% [markdown]
# data.iloc[]

# %%
decade_boy_count = decade.iloc[decade.index.get_level_values(3)=='M'].reset_index(level=[0,1,3], drop=True)#取出男性的数据，丢掉没用的列
decade_boy_count.head()

from pylab import mpl 
mpl.rcParams['font.sans-serif'] = ['SimHei']#为了显示中文
decade_boy_total = data_decades[data_decades['Gender']=='M'].groupby('decade').Count.sum()#计算每个年代里面男性的Count值加总
decade_boy_pct = (decade_boy_count/decade_boy_total*100).round(2)#算比例，保留2位小数
ax = decade_boy_pct.plot.barh(title='各年代最流行的男性名字')#画横向的bar图
ax.set_ylabel('')
ax.set_xlabel('百分比')
#ax.set(axis_bgcolor='#f2eada')
# Out:
# Text(0.5, 0, '百分比')

# %%
decade_girl_count = decade.iloc[decade.index.get_level_values(3)=='F'].reset_index(level=[0,1,3], drop=True)#同样取出女的数据
decade_girl_total = data_decades[data_decades['Gender']=='F'].groupby('decade').Count.sum()
decade_girl_pct = (decade_girl_count/decade_girl_total*100).round(2)
ax = decade_girl_pct.plot.barh(title='各年代最流行的女性名字')
ax.set_ylabel('')
ax.set_xlabel('百分比')
#ax.set(axis_bgcolor='#feeeed')
# Out:
# Text(0.5, 0, '百分比')

# %% [markdown]
# ## 3. 以前很流行，现在不流行的名字

# %% [markdown]
# ### -男

# %%
data_popular_former = data[(data['Year'] < 1950) & (data['Count'] > 10500) & (data['Gender'] == 'M')]#取出1950年前，Count>10500的男数据
data_not_popular_now = data[(data['Year'] > 2000) & (data['Count'] < 1000) & (data['Gender'] == 'M')]#取出2000年后，Count<1000的男数据

# %%
boys_names_popular_former = list(set(list(data_popular_former.Name.unique())) & set(list(data_not_popular_now.Name.unique())))#找到交集
boys_names_popular_former
# Out:
# ['Ronald',
#  'Roger',
#  'Harold',
#  'Bruce',
#  'Arthur',
#  'Walter',
#  'Dennis',
#  'Douglas',
#  'Terry',
#  'Gregory',
#  'Gerald',
#  'Jerry',
#  'Gary',
#  'Frank',
#  'Donald',
#  'Larry']

# %%
boys_names_popular_former_data = data[(data['Name'].isin(boys_names_popular_former)) & (data['Year']>=1920) & (data['Gender']=='M')]
#取出名字在boys_names_popular_former里，且Year>1920的男的数据
boys_names_popular_former_data.head()
#boys_names_popular_former_data.Count.max()
# Out:
#             Id    Name  Year Gender  Count
# 175228  175229   Frank  1920      M  16432
# 175231  175232  Harold  1920      M  13679
# 175232  175233  Walter  1920      M  13294
# 175235  175236  Donald  1920      M  11941
# 175237  175238  Arthur  1920      M  10236

# %%
from pyecharts.charts import Page
import pyecharts.options as opts
attr = list(range(1920, 2018))
attr=[str(i) for i in attr]#转字符串
# #line = Line("",width=800, height=600)
# line = Line()
# for name in boys_names_popular_former:
#    v = list(boys_names_popular_former_data[boys_names_popular_former_data['Name']==name].Count.values)
#    line.add(name, attr, v, legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
#    #print(name,attr,v)
# line

line = Line()#创建Line()
line.add_xaxis(attr)#横坐标
for name in boys_names_popular_former:#遍历每个名字
    v = list(boys_names_popular_former_data[boys_names_popular_former_data['Name']==name].Count.values)#计算相应名字的count值
    v = [int(i) for i in v]#转int
    line.add_yaxis(name, v,label_opts=opts.LabelOpts(is_show=False))#不加标签

line.render_notebook()#画图
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="8f024257ad7c49f6b153bbc952fc9402" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_8f024257ad7c49f6b153bbc952fc9402 = echarts.init(
#             document.getElementById('8f024257ad7c49f6b153bbc952fc9402'), 'white', {renderer: 'canvas'});
#         var option_8f024257ad7c49f6b153bbc952fc9402 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "Ronald",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1920",
#                     832
#                 ],
#                 [
#                     "1921",
#                     993
#                 ],
#                 [
#                     "1922",
#                     1042
#                 ],
#                 [
#                     "1923",
#                     1148
#                 ],
#                 [
#                     "1924",
#                     1360
#                 ],
#                 [
#                     "1925",
#                     1676
#                 ],
#                 [
#                     "1926",
#                     2287
#                 ],
#                 [
#                     "1927",
#                     3111
#                 ],
#                 [
#                     "1928",
#                     3976
#                 ],
#                 [
#                     "1929",
#                     4477
#                 ],
#                 [
#                     "1930",
#                     5634
#                 ],
#                 [
#                     "1931",
#                     6726
#                 ],
#                 [
#                     "1932",
#                     11139
#                 ],
#                 [
#                     "1933",
#                     12061
#                 ],
#                 [
#                     "1934",
#                     14084
#                 ],
#                 [
#                     "1935",
#                     15483
#                 ],
#                 [
#                     "1936",
#                     16920
#                 ],
#                 [
#                     "1937",
#                     18136
#                 ],
#                 [
#                     "1938",
#                     20294
#                 ],
#                 [
#                     "1939",
#                     19835
#                 ],
#                 [
#                     "1940",
#                     20729
#                 ],
#                 [
#                     "1941",
#                     24397
#                 ],
#                 [
#                     "1942",
#                     27134
#                 ],
#                 [
#                     "1943",
#                     29235
#                 ],
#                 [
#                     "1944",
#                     25509
#                 ],
#                 [
#                     "1945",
#                     23665
#                 ],
#                 [
#                     "1946",
#                     31853
#                 ],
#                 [
#                     "1947",
#                     34884
#                 ],
#                 [
#                     "1948",
#                     33516
#                 ],
#                 [
#                     "1949",
#                     31495
#                 ],
#                 [
#                     "1950",
#                     29916
#                 ],
#                 [
#                     "1951",
#                     29044
#                 ],
#                 [
#                     "1952",
#                     27809
#                 ],
#                 [
#                     "1953",
#                     27704
#                 ],
#                 [
#                     "1954",
#                     27596
#                 ],
#                 [
#                     "1955",
#                     26163
#                 ],
#                 [
#                     "1956",
#                     27725
#                 ],
#                 [
#                     "1957",
#                     27181
#                 ],
#                 [
#                     "1958",
#                     24807
#                 ],
#                 [
#                     "1959",
#                     23108
#                 ],
#                 [
#                     "1960",
#                     21700
#                 ],
#                 [
#                     "1961",
#                     20816
#                 ],
#                 [
#                     "1962",
#                     19975
#                 ],
#                 [
#                     "1963",
#                     19781
#                 ],
#                 [
#                     "1964",
#                     18840
#                 ],
#                 [
#                     "1965",
#                     17620
#                 ],
#                 [
#                     "1966",
#                     16957
#                 ],
#                 [
#                     "1967",
#                     16439
#                 ],
#                 [
#                     "1968",
#                     15423
#                 ],
#                 [
#                     "1969",
#                     14623
#                 ],
#                 [
#                     "1970",
#                     13616
#                 ],
#                 [
#                     "1971",
#                     11634
#                 ],
#                 [
#                     "1972",
#                     9511
#                 ],
#                 [
#                     "1973",
#                     8327
#                 ],
#                 [
#                     "1974",
#                     7667
#                 ],
#                 [
#                     "1975",
#                     7066
#                 ],
#                 [
#                     "1976",
#                     6461
#                 ],
#                 [
#                     "1977",
#                     6030
#                 ],
#                 [
#                     "1978",
#                     5757
#                 ],
#                 [
#                     "1979",
#                     5702
#                 ],
#                 [
#                     "1980",
#                     5760
#                 ],
#                 [
#                     "1981",
#                     5533
#                 ],
#                 [
#                     "1982",
#                     5207
#                 ],
#                 [
#                     "1983",
#                     4708
#                 ],
#                 [
#                     "1984",
#                     4507
#                 ],
#                 [
#                     "1985",
#                     4299
#                 ],
#                 [
#                     "1986",
#                     4222
#                 ],
#                 [
#                     "1987",
#                     4153
#                 ],
#                 [
#                     "1988",
#                     4173
#                 ],
#                 [
#                     "1989",
#                     4105
#                 ],
#                 [
#                     "1990",
#                     3900
#                 ],
#                 [
#                     "1991",
#                     3669
#                 ],
#                 [
#                     "1992",
#                     3223
#                 ],
#                 [
#                     "1993",
#                     2880
#                 ],
#                 [
#                     "1994",

# %% [markdown]
# ### -女

# %%
data_popular_former = data[(data['Year'] < 1950) & (data['Count'] > 22500) & (data['Gender'] == 'F')]
data_not_popular_now = data[(data['Year'] > 2000) & (data['Count'] < 1000) & (data['Gender'] == 'F')]

# %%
girl_names_popular_former = list(set(list(data_popular_former.Name.unique())) & set(list(data_not_popular_now.Name.unique())))

# %%
girl_names_popular_former_data = data[(data['Name'].isin(girl_names_popular_former)) & (data['Year']>=1920) & (data['Gender']=='F')]

# %%
attr = list(range(1920, 2018))
attr=[str(i) for i in attr]#转字符串
#line = Line("",width=800, height=600)
# for name in girl_names_popular_former:
#     v = list(girl_names_popular_former_data[girl_names_popular_former_data['Name']==name].Count.values)
#     line.add(name, attr, v,legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
# line

line = Line()#创建Line()
line.add_xaxis(attr)#横坐标
for name in girl_names_popular_former:#遍历每个名字
    v = list(girl_names_popular_former_data[girl_names_popular_former_data['Name']==name].Count.values)#计算相应名字的count值
    v = [int(i) for i in v]#转int
    line.add_yaxis(name, v,label_opts=opts.LabelOpts(is_show=False))#不加标签

line.render_notebook()#画图
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="00afcb263c054fdb857019ac106ea7d5" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_00afcb263c054fdb857019ac106ea7d5 = echarts.init(
#             document.getElementById('00afcb263c054fdb857019ac106ea7d5'), 'white', {renderer: 'canvas'});
#         var option_00afcb263c054fdb857019ac106ea7d5 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "Susan",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1920",
#                     850
#                 ],
#                 [
#                     "1921",
#                     846
#                 ],
#                 [
#                     "1922",
#                     795
#                 ],
#                 [
#                     "1923",
#                     812
#                 ],
#                 [
#                     "1924",
#                     832
#                 ],
#                 [
#                     "1925",
#                     862
#                 ],
#                 [
#                     "1926",
#                     855
#                 ],
#                 [
#                     "1927",
#                     868
#                 ],
#                 [
#                     "1928",
#                     812
#                 ],
#                 [
#                     "1929",
#                     875
#                 ],
#                 [
#                     "1930",
#                     1004
#                 ],
#                 [
#                     "1931",
#                     1005
#                 ],
#                 [
#                     "1932",
#                     1227
#                 ],
#                 [
#                     "1933",
#                     1263
#                 ],
#                 [
#                     "1934",
#                     1492
#                 ],
#                 [
#                     "1935",
#                     1801
#                 ],
#                 [
#                     "1936",
#                     2155
#                 ],
#                 [
#                     "1937",
#                     2643
#                 ],
#                 [
#                     "1938",
#                     3555
#                 ],
#                 [
#                     "1939",
#                     4886
#                 ],
#                 [
#                     "1940",
#                     6755
#                 ],
#                 [
#                     "1941",
#                     8889
#                 ],
#                 [
#                     "1942",
#                     12016
#                 ],
#                 [
#                     "1943",
#                     14888
#                 ],
#                 [
#                     "1944",
#                     16329
#                 ],
#                 [
#                     "1945",
#                     19224
#                 ],
#                 [
#                     "1946",
#                     28266
#                 ],
#                 [
#                     "1947",
#                     31953
#                 ],
#                 [
#                     "1948",
#                     35985
#                 ],
#                 [
#                     "1949",
#                     37707
#                 ],
#                 [
#                     "1950",
#                     38018
#                 ],
#                 [
#                     "1951",
#                     40227
#                 ],
#                 [
#                     "1952",
#                     41350
#                 ],
#                 [
#                     "1953",
#                     44285
#                 ],
#                 [
#                     "1954",
#                     47158
#                 ],
#                 [
#                     "1955",
#                     47397
#                 ],
#                 [
#                     "1956",
#                     46567
#                 ],
#                 [
#                     "1957",
#                     45951
#                 ],
#                 [
#                     "1958",
#                     45172
#                 ],
#                 [
#                     "1959",
#                     41598
#                 ],
#                 [
#                     "1960",
#                     39200
#                 ],
#                 [
#                     "1961",
#                     37521
#                 ],
#                 [
#                     "1962",
#                     35744
#                 ],
#                 [
#                     "1963",
#                     33997
#                 ],
#                 [
#                     "1964",
#                     31514
#                 ],
#                 [
#                     "1965",
#                     26327
#                 ],
#                 [
#                     "1966",
#                     23775
#                 ],
#                 [
#                     "1967",
#                     22262
#                 ],
#                 [
#                     "1968",
#                     19505
#                 ],
#                 [
#                     "1969",
#                     17808
#                 ],
#                 [
#                     "1970",
#                     15739
#                 ],
#                 [
#                     "1971",
#                     13779
#                 ],
#                 [
#                     "1972",
#                     10575
#                 ],
#                 [
#                     "1973",
#                     9284
#                 ],
#                 [
#                     "1974",
#                     8472
#                 ],
#                 [
#                     "1975",
#                     7487
#                 ],
#                 [
#                     "1976",
#                     6406
#                 ],
#                 [
#                     "1977",
#                     5955
#                 ],
#                 [
#                     "1978",
#                     5419
#                 ],
#                 [
#                     "1979",
#                     5199
#                 ],
#                 [
#                     "1980",
#                     4703
#                 ],
#                 [
#                     "1981",
#                     4247
#                 ],
#                 [
#                     "1982",
#                     3964
#                 ],
#                 [
#                     "1983",
#                     3353
#                 ],
#                 [
#                     "1984",
#                     3114
#                 ],
#                 [
#                     "1985",
#                     2662
#                 ],
#                 [
#                     "1986",
#                     2391
#                 ],
#                 [
#                     "1987",
#                     2249
#                 ],
#                 [
#                     "1988",
#                     2060
#                 ],
#                 [
#                     "1989",
#                     1799
#                 ],
#                 [
#                     "1990",
#                     1687
#                 ],
#                 [
#                     "1991",
#                     1478
#                 ],
#                 [
#                     "1992",
#                     1372
#                 ],
#                 [
#                     "1993",
#                     1199
#                 ],
#                 [
#                     "1994",

# %% [markdown]
# ## 4. 2000年后越来越流行的名字

# %% [markdown]
# ### - 男

# %%
data_popular_now = data[(data['Year']>=2000)&(data['Gender'] =='M')&(data['Count']>7000)]#取出规定Year<=2000和Gender=M、Count>7000的数据
data_popular_now = data_popular_now.pivot(index='Name', columns='Year',values='Count')#Year和Name交叉表，内容为Count
data_popular_now.head()
# Out:
# Year      2000    2001    2002     2003    2004    2005     2006     2007  \
# Name
# Aaron   9553.0  9535.0  9001.0   8865.0  8389.0  7802.0   8296.0   8935.0
# Adam    8133.0  7752.0  7749.0   7683.0  7471.0     NaN      NaN      NaN
# Adrian     NaN     NaN     NaN      NaN     NaN     NaN   7381.0   7733.0
# Aidan      NaN     NaN     NaN  10062.0  9821.0  9758.0  10034.0   8420.0
# Aiden      NaN     NaN     NaN      NaN  7159.0  9081.0  11583.0  13101.0
#
# Year       2008     2009     2010     2011     2012     2013     2014  \
# Name
# Aaron    8537.0   7969.0   7461.0   7613.0   7530.0   7301.0   7391.0
# Adam        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Adrian   7927.0   7631.0   7405.0   7333.0      NaN      NaN      NaN
# Aidan    7698.0      NaN      NaN      NaN      NaN      NaN      NaN
# Aiden   15578.0  16017.0  15535.0  15492.0  14896.0  13615.0  13394.0
#
# Year       2015     2016     2017
# Name
# Aaron    7152.0   7150.0   7165.0
# Adam        NaN      NaN      NaN
# Adrian      NaN      NaN      NaN
# Aidan       NaN      NaN      NaN
# Aiden   13449.0  12212.0  11259.0

# %%
year = pd.DataFrame({'Year':list(range(2000, 2018))}, index=list(range(2000, 2018)))#做义工2000-2018的dataframe
year
# Out:
#       Year
# 2000  2000
# 2001  2001
# 2002  2002
# 2003  2003
# 2004  2004
# 2005  2005
# 2006  2006
# 2007  2007
# 2008  2008
# 2009  2009
# 2010  2010
# 2011  2011
# 2012  2012
# 2013  2013
# 2014  2014
# 2015  2015
# 2016  2016
# 2017  2017

# %%
data_popular_now_corr = data_popular_now.corrwith(year['Year'], axis=1)#计算每个name与year的的相关性
boys_names_popular_now = list(data_popular_now_corr[data_popular_now_corr > 0.8].index)#取出高相关的人
boys_names_popular_now
# Out:
# F:\Anaconda\lib\site-packages\numpy\lib\function_base.py:2522: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# F:\Anaconda\lib\site-packages\numpy\lib\function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# ['Carter',
#  'Elijah',
#  'Grayson',
#  'Henry',
#  'Julian',
#  'Levi',
#  'Liam',
#  'Lincoln',
#  'Lucas',
#  'Mason',
#  'Noah',
#  'Oliver',
#  'Owen',
#  'Sebastian',
#  'Wyatt']

# %%
boys_names_popular_now_data = data[(data['Name'].isin(boys_names_popular_now)) & (data['Year']>=1920) & (data['Gender']=='M')]
#取出名字和boys_names_popular_now一样，且Year>1920，男的数据
boys_names_popular_now_data.head()
# Out:
#             Id    Name  Year Gender  Count
# 175236  175237   Henry  1920      M  11304
# 175354  175355  Oliver  1920      M   1164
# 175414  175415  Julian  1920      M    693
# 175436  175437    Owen  1920      M    598
# 175575  175576  Elijah  1920      M    277

# %%
boys_names_popular_now_data = boys_names_popular_now_data.pivot(index='Name', columns='Year',values='Count').reset_index().melt('Name', value_name='Count')
#Name和Year交叉，且转成dataframe
boys_names_popular_now_data.head()
# Out:
#       Name  Year    Count
# 0   Carter  1920     98.0
# 1   Elijah  1920    277.0
# 2  Grayson  1920     28.0
# 3    Henry  1920  11304.0
# 4   Julian  1920    693.0

# %%
attr = list(range(1920, 2018))
attr=[str(i) for i in attr]#转字符串
# line = Line("",width=800, height=600)
# for name in boys_names_popular_now:
#     v = list(boys_names_popular_now_data[boys_names_popular_now_data['Name']==name].Count.values)
#     line.add(name, attr, v, legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
# line

line = Line()#创建Line()
line.add_xaxis(attr)#横坐标
for name in boys_names_popular_now:#遍历每个名字
    v0 = list(boys_names_popular_now_data[boys_names_popular_now_data['Name']==name].Count.values)#计算相应名字的count值
    v=[]
    for i in v0:
        if i==i:
            v.append(int(i))#转int
        else:
            v.append(0)#NaN值处理成0
    line.add_yaxis(name, v,label_opts=opts.LabelOpts(is_show=False))#不加标签

line.render_notebook()#画图
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="0bb24f6bcc9f477e9d9b732105d229d1" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_0bb24f6bcc9f477e9d9b732105d229d1 = echarts.init(
#             document.getElementById('0bb24f6bcc9f477e9d9b732105d229d1'), 'white', {renderer: 'canvas'});
#         var option_0bb24f6bcc9f477e9d9b732105d229d1 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "Carter",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1920",
#                     98
#                 ],
#                 [
#                     "1921",
#                     83
#                 ],
#                 [
#                     "1922",
#                     93
#                 ],
#                 [
#                     "1923",
#                     84
#                 ],
#                 [
#                     "1924",
#                     112
#                 ],
#                 [
#                     "1925",
#                     88
#                 ],
#                 [
#                     "1926",
#                     89
#                 ],
#                 [
#                     "1927",
#                     85
#                 ],
#                 [
#                     "1928",
#                     78
#                 ],
#                 [
#                     "1929",
#                     71
#                 ],
#                 [
#                     "1930",
#                     62
#                 ],
#                 [
#                     "1931",
#                     78
#                 ],
#                 [
#                     "1932",
#                     68
#                 ],
#                 [
#                     "1933",
#                     77
#                 ],
#                 [
#                     "1934",
#                     97
#                 ],
#                 [
#                     "1935",
#                     101
#                 ],
#                 [
#                     "1936",
#                     98
#                 ],
#                 [
#                     "1937",
#                     99
#                 ],
#                 [
#                     "1938",
#                     106
#                 ],
#                 [
#                     "1939",
#                     77
#                 ],
#                 [
#                     "1940",
#                     88
#                 ],
#                 [
#                     "1941",
#                     109
#                 ],
#                 [
#                     "1942",
#                     112
#                 ],
#                 [
#                     "1943",
#                     130
#                 ],
#                 [
#                     "1944",
#                     122
#                 ],
#                 [
#                     "1945",
#                     125
#                 ],
#                 [
#                     "1946",
#                     148
#                 ],
#                 [
#                     "1947",
#                     178
#                 ],
#                 [
#                     "1948",
#                     150
#                 ],
#                 [
#                     "1949",
#                     178
#                 ],
#                 [
#                     "1950",
#                     170
#                 ],
#                 [
#                     "1951",
#                     172
#                 ],
#                 [
#                     "1952",
#                     156
#                 ],
#                 [
#                     "1953",
#                     161
#                 ],
#                 [
#                     "1954",
#                     190
#                 ],
#                 [
#                     "1955",
#                     150
#                 ],
#                 [
#                     "1956",
#                     176
#                 ],
#                 [
#                     "1957",
#                     140
#                 ],
#                 [
#                     "1958",
#                     164
#                 ],
#                 [
#                     "1959",
#                     134
#                 ],
#                 [
#                     "1960",
#                     139
#                 ],
#                 [
#                     "1961",
#                     132
#                 ],
#                 [
#                     "1962",
#                     130
#                 ],
#                 [
#                     "1963",
#                     159
#                 ],
#                 [
#                     "1964",
#                     133
#                 ],
#                 [
#                     "1965",
#                     114
#                 ],
#                 [
#                     "1966",
#                     127
#                 ],
#                 [
#                     "1967",
#                     141
#                 ],
#                 [
#                     "1968",
#                     123
#                 ],
#                 [
#                     "1969",
#                     150
#                 ],
#                 [
#                     "1970",
#                     156
#                 ],
#                 [
#                     "1971",
#                     198
#                 ],
#                 [
#                     "1972",
#                     164
#                 ],
#                 [
#                     "1973",
#                     131
#                 ],
#                 [
#                     "1974",
#                     142
#                 ],
#                 [
#                     "1975",
#                     163
#                 ],
#                 [
#                     "1976",
#                     158
#                 ],
#                 [
#                     "1977",
#                     122
#                 ],
#                 [
#                     "1978",
#                     71
#                 ],
#                 [
#                     "1979",
#                     65
#                 ],
#                 [
#                     "1980",
#                     91
#                 ],
#                 [
#                     "1981",
#                     88
#                 ],
#                 [
#                     "1982",
#                     118
#                 ],
#                 [
#                     "1983",
#                     119
#                 ],
#                 [
#                     "1984",
#                     134
#                 ],
#                 [
#                     "1985",
#                     176
#                 ],
#                 [
#                     "1986",
#                     182
#                 ],
#                 [
#                     "1987",
#                     212
#                 ],
#                 [
#                     "1988",
#                     265
#                 ],
#                 [
#                     "1989",
#                     294
#                 ],
#                 [
#                     "1990",
#                     333
#                 ],
#                 [
#                     "1991",
#                     391
#                 ],
#                 [
#                     "1992",
#                     487
#                 ],
#                 [
#                     "1993",
#                     550
#                 ],
#                 [
#                     "1994",
#                     543
#                 ],
#                 [
#                     "1995",
#                     919
#                 ],

# %% [markdown]
# ### -女

# %%
data_popular_now = data[(data['Year']>=2000)&(data['Gender'] =='F')&(data['Count']>6000)]
data_popular_now = data_popular_now.pivot(index='Name', columns='Year',values='Count')

# %%
data_popular_now_corr = data_popular_now.corrwith(year['Year'], axis=1)
girls_names_popular_now = list(data_popular_now_corr[data_popular_now_corr > 0.7].index)

# %%
girls_names_popular_now_data = data[(data['Name'].isin(girls_names_popular_now)) & (data['Year']>=1920) & (data['Gender']=='F')]

# %%
girls_names_popular_now_data = girls_names_popular_now_data.pivot(index='Name', columns='Year',values='Count').reset_index().melt('Name', value_name='Count')

# %%
attr = list(range(1920, 2018))
attr=[str(i) for i in attr]#转字符串
# line = Line("",width=800, height=600)
# for name in girls_names_popular_now:
#     v = list(girls_names_popular_now_data[girls_names_popular_now_data['Name']==name].Count.values)
#     line.add(name, attr, v, legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
# line

line = Line()#创建Line()
line.add_xaxis(attr)#横坐标
for name in girls_names_popular_now:#遍历每个名字
    v0 = list(girls_names_popular_now_data[girls_names_popular_now_data['Name']==name].Count.values)#计算相应名字的count值
    v=[]
    for i in v0:
        if i==i:
            v.append(int(i))#转int
        else:
            v.append(0)#NaN值处理成0
    line.add_yaxis(name, v,label_opts=opts.LabelOpts(is_show=False))#不加标签

line.render_notebook()#画图
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="4832268682ad4d2994ec351d7fe636b9" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_4832268682ad4d2994ec351d7fe636b9 = echarts.init(
#             document.getElementById('4832268682ad4d2994ec351d7fe636b9'), 'white', {renderer: 'canvas'});
#         var option_4832268682ad4d2994ec351d7fe636b9 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "Amelia",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1920",
#                     1054
#                 ],
#                 [
#                     "1921",
#                     995
#                 ],
#                 [
#                     "1922",
#                     1032
#                 ],
#                 [
#                     "1923",
#                     965
#                 ],
#                 [
#                     "1924",
#                     910
#                 ],
#                 [
#                     "1925",
#                     889
#                 ],
#                 [
#                     "1926",
#                     746
#                 ],
#                 [
#                     "1927",
#                     755
#                 ],
#                 [
#                     "1928",
#                     755
#                 ],
#                 [
#                     "1929",
#                     687
#                 ],
#                 [
#                     "1930",
#                     679
#                 ],
#                 [
#                     "1931",
#                     591
#                 ],
#                 [
#                     "1932",
#                     637
#                 ],
#                 [
#                     "1933",
#                     608
#                 ],
#                 [
#                     "1934",
#                     553
#                 ],
#                 [
#                     "1935",
#                     604
#                 ],
#                 [
#                     "1936",
#                     581
#                 ],
#                 [
#                     "1937",
#                     646
#                 ],
#                 [
#                     "1938",
#                     570
#                 ],
#                 [
#                     "1939",
#                     490
#                 ],
#                 [
#                     "1940",
#                     504
#                 ],
#                 [
#                     "1941",
#                     529
#                 ],
#                 [
#                     "1942",
#                     543
#                 ],
#                 [
#                     "1943",
#                     560
#                 ],
#                 [
#                     "1944",
#                     475
#                 ],
#                 [
#                     "1945",
#                     475
#                 ],
#                 [
#                     "1946",
#                     547
#                 ],
#                 [
#                     "1947",
#                     538
#                 ],
#                 [
#                     "1948",
#                     564
#                 ],
#                 [
#                     "1949",
#                     589
#                 ],
#                 [
#                     "1950",
#                     483
#                 ],
#                 [
#                     "1951",
#                     533
#                 ],
#                 [
#                     "1952",
#                     550
#                 ],
#                 [
#                     "1953",
#                     550
#                 ],
#                 [
#                     "1954",
#                     511
#                 ],
#                 [
#                     "1955",
#                     531
#                 ],
#                 [
#                     "1956",
#                     525
#                 ],
#                 [
#                     "1957",
#                     522
#                 ],
#                 [
#                     "1958",
#                     483
#                 ],
#                 [
#                     "1959",
#                     501
#                 ],
#                 [
#                     "1960",
#                     542
#                 ],
#                 [
#                     "1961",
#                     571
#                 ],
#                 [
#                     "1962",
#                     493
#                 ],
#                 [
#                     "1963",
#                     503
#                 ],
#                 [
#                     "1964",
#                     503
#                 ],
#                 [
#                     "1965",
#                     475
#                 ],
#                 [
#                     "1966",
#                     430
#                 ],
#                 [
#                     "1967",
#                     450
#                 ],
#                 [
#                     "1968",
#                     390
#                 ],
#                 [
#                     "1969",
#                     465
#                 ],
#                 [
#                     "1970",
#                     493
#                 ],
#                 [
#                     "1971",
#                     482
#                 ],
#                 [
#                     "1972",
#                     405
#                 ],
#                 [
#                     "1973",
#                     442
#                 ],
#                 [
#                     "1974",
#                     506
#                 ],
#                 [
#                     "1975",
#                     524
#                 ],
#                 [
#                     "1976",
#                     523
#                 ],
#                 [
#                     "1977",
#                     601
#                 ],
#                 [
#                     "1978",
#                     643
#                 ],
#                 [
#                     "1979",
#                     702
#                 ],
#                 [
#                     "1980",
#                     768
#                 ],
#                 [
#                     "1981",
#                     849
#                 ],
#                 [
#                     "1982",
#                     833
#                 ],
#                 [
#                     "1983",
#                     759
#                 ],
#                 [
#                     "1984",
#                     1094
#                 ],
#                 [
#                     "1985",
#                     1014
#                 ],
#                 [
#                     "1986",
#                     1018
#                 ],
#                 [
#                     "1987",
#                     1006
#                 ],
#                 [
#                     "1988",
#                     1128
#                 ],
#                 [
#                     "1989",
#                     1265
#                 ],
#                 [
#                     "1990",
#                     1511
#                 ],
#                 [
#                     "1991",
#                     1536
#                 ],
#                 [
#                     "1992",
#                     1344
#                 ],
#                 [
#                     "1993",
#                     1248
#                 ],
#                 [
#                     "1994",
#                     1253
#                 ],
#                 [
#                     "1995",

# %% [markdown]
# ## 5. 影响美国人取名的因素：体育明星、电视明星

# %%
# from pyecharts import Overlap
# def name_trend(name, data, gender=['M','F'], year=1920, dodge = 500):
#     if isinstance(gender, str):
#         name_data = data[(data['Name'] == name)&(data['Gender']==gender)&(data['Year']>=year)]
#         attr = list(name_data['Year'].values)
#         bar = Bar(name)
#         bar.add("", attr, list(name_data['Count'].values), mark_line=["average"], mark_point=["max", "min"],
#                legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
#         line = Line()
#         line.add("", attr, list(name_data['Count'].values + dodge))
        
#     else:
#         name_data = data[(data['Name'] == name)&(data['Year']>=year)]
#         attr = list(range(year, 2018))
#         v1 = name_data[name_data['Gender']==gender[0]].Count.values
#         v2 = name_data[name_data['Gender']==gender[1]].Count.values
#         bar = Bar(name)
#         bar.add("男", attr, list(v1), legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
#         bar.add("女", attr, list(v2), legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
#         line = Line()
#         line.add("", attr, list(v1 + dodge))
#         line.add("", attr, list(v2 + dodge))
    
#     overlap = Overlap()
#     overlap.add(bar)
#     overlap.add(line)
#     return overlap

def name_trend(name, data, gender=['M','F'], year=1920, dodge = 500):
    if isinstance(gender, str):#若gender为字符串（为空）
        name_data = data[(data['Name'] == name)&(data['Gender']==gender)&(data['Year']>=year)]#取出特定名字、性别、年份的数据
        attr = list(name_data['Year'].values)#取出年份的值
        attr=[str(i) for i in attr]#转字符串
        v1=name_data['Count'].values
        v1= [int(i) for i in v1]#转int
        v1d= [int(i)+dodge for i in v1]#转int
        bar = Bar()#画bar图，
        bar.add_xaxis(attr)#bar的横坐标
        bar.add_yaxis(name, list(v1))#第一组数据
        bar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))#不展示点标签
        line = Line()
        line.add_xaxis(attr)#line的横坐标
        line.add_yaxis(name, v1d,label_opts=opts.LabelOpts(is_show=False))#不加标签
        
    else:
        name_data = data[(data['Name'] == name)&(data['Year']>=year)]#取出特定名字、年份的数据
        attr = list(range(year, 2018))#取出该年份到2018的年份
        attr=[str(i) for i in attr]#转字符串
        v1 = name_data[name_data['Gender']==gender[0]].Count.values#取出男性的数据
        v2 = name_data[name_data['Gender']==gender[1]].Count.values#取出女性的数据
        v1= [int(i) for i in v1]#转int
        v2= [int(i) for i in v2]
        v1d= [int(i)+dodge for i in v1]#转int
        v2d= [int(i)+dodge for i in v2]
        bar = Bar()#画男性和女性的bar图
        bar.add_xaxis(attr)#bar的横坐标
        bar.add_yaxis("男", list(v1))#第一组数据
        bar.add_yaxis("女", list(v2))#第一组数据
        bar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))#不展示点标签
        line = Line()
        line.add_xaxis(attr)#line的横坐标
        line.add_yaxis("男", v1d,label_opts=opts.LabelOpts(is_show=False))#不加标签)
        line.add_yaxis("女", v2d,label_opts=opts.LabelOpts(is_show=False))#不加标签)

    bar.overlap(line)#折线图叠在bar图上
    return bar.render_notebook()#画图

# %%
from example.commons import Collector, Faker#例子而已
from pyecharts import options as opts
from pyecharts.charts import Bar, Line, Page, Scatter

v1 = [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]
v2 = [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]
v3 = [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2]


bar = Bar()
bar.add_xaxis(Faker.months)#bar的横坐标
bar.add_yaxis("蒸发量", v1)#第一组数据
bar.add_yaxis("降水量", v2)#第二组数据
bar.extend_axis(yaxis=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter="{value} °C"), interval=5))#右纵坐标格式
bar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))#不展示点标签
bar.set_global_opts(title_opts=opts.TitleOpts(title="Overlap-bar+line"),
                            yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter="{value} ml")),)#左纵坐标格式

line = Line().add_xaxis(Faker.months).add_yaxis("平均温度", v3, yaxis_index=1)#折线图
bar.overlap(line)#折线图叠在bar图上
bar.render_notebook()#画图
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="a70998f43c9a4e3f9cf29e6d002d352f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_a70998f43c9a4e3f9cf29e6d002d352f = echarts.init(
#             document.getElementById('a70998f43c9a4e3f9cf29e6d002d352f'), 'white', {renderer: 'canvas'});
#         var option_a70998f43c9a4e3f9cf29e6d002d352f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u6e29\u5ea6",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1\u6708",
#                     2.0
#                 ],
#                 [
#                     "2\u6708",
#                     2.2
#                 ],
#                 [
#                     "3\u6708",
#                     3.3
#                 ],
#                 [
#                     "4\u6708",
#                     4.5
#                 ],
#                 [
#                     "5\u6708",
#                     6.3
#                 ],
#                 [
#                     "6\u6708",
#                     10.2
#                 ],
#                 [
#                     "7\u6708",
#                     20.3
#                 ],
#                 [
#                     "8\u6708",
#                     23.4
#                 ],
#                 [
#                     "9\u6708",
#                     23.0
#                 ],
#                 [
#                     "10\u6708",
#                     16.5
#                 ],
#                 [
#                     "11\u6708",
#                     12.0
#                 ],
#                 [
#                     "12\u6708",
#                     6.2
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u84b8\u53d1\u91cf",
#                 "\u964d\u6c34\u91cf",
#                 "\u5e73\u5747\u6e29\u5ea6"
#             ],
#             "selected": {
#                 "\u84b8\u53d1\u91cf": true,
#                 "\u964d\u6c34\u91cf": true
#             },
#             "show": true
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708",
#                 "8\u6708",
#                 "9\u6708",
#                 "10\u6708",
#                 "11\u6708",
#                 "12\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} ml"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "interval": 5,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} \u00b0C"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Overlap-bar+line"
#         }
#     ]
# };
#         chart_a70998f43c9a4e3f9cf29e6d002d352f.setOption(option_a70998f43c9a4e3f9cf29e6d002d352f);
#     });
# </script>

# %% [markdown]
# - 体育明星：Jordan, Kobe, Lebron

# %%
name_trend('Jordan',data,gender='M',year=1960)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="ee396d645b8f489aa231e8c397bf8eaf" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_ee396d645b8f489aa231e8c397bf8eaf = echarts.init(
#             document.getElementById('ee396d645b8f489aa231e8c397bf8eaf'), 'white', {renderer: 'canvas'});
#         var option_ee396d645b8f489aa231e8c397bf8eaf = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Jordan",
#             "data": [
#                 137,
#                 187,
#                 182,
#                 154,
#                 165,
#                 179,
#                 212,
#                 221,
#                 189,
#                 223,
#                 279,
#                 290,
#                 258,
#                 305,
#                 369,
#                 397,
#                 517,
#                 649,
#                 981,
#                 1406,
#                 1619,
#                 2922,
#                 3535,
#                 4013,
#                 4539,
#                 5456,
#                 7300,
#                 8408,
#                 8485,
#                 10871,
#                 16133,
#                 16013,
#                 14029,
#                 14753,
#                 14160,
#                 13567,
#                 13852,
#                 14759,
#                 14409,
#                 13051,
#                 12167,
#                 10813,
#                 11147,
#                 10328,
#                 9554,
#                 9394,
#                 9923,
#                 10046,
#                 9086,
#                 8651,
#                 8230,
#                 8065,
#                 7802,
#                 7189,
#                 6860,
#                 6287,
#                 5618,
#                 5114
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "Jordan",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1960",
#                     637
#                 ],
#                 [
#                     "1961",
#                     687
#                 ],
#                 [
#                     "1962",
#                     682
#                 ],
#                 [
#                     "1963",
#                     654
#                 ],
#                 [
#                     "1964",
#                     665
#                 ],
#                 [
#                     "1965",
#                     679
#                 ],
#                 [
#                     "1966",
#                     712
#                 ],
#                 [
#                     "1967",
#                     721
#                 ],
#                 [
#                     "1968",
#                     689
#                 ],
#                 [
#                     "1969",
#                     723
#                 ],
#                 [
#                     "1970",
#                     779
#                 ],
#                 [
#                     "1971",
#                     790
#                 ],
#                 [
#                     "1972",
#                     758
#                 ],
#                 [
#                     "1973",
#                     805
#                 ],
#                 [
#                     "1974",
#                     869
#                 ],
#                 [
#                     "1975",
#                     897
#                 ],
#                 [
#                     "1976",
#                     1017
#                 ],
#                 [
#                     "1977",
#                     1149
#                 ],
#                 [
#                     "1978",
#                     1481
#                 ],
#                 [
#                     "1979",
#                     1906
#                 ],
#                 [
#                     "1980",
#                     2119
#                 ],
#                 [
#                     "1981",
#                     3422
#                 ],
#                 [
#                     "1982",
#                     4035
#                 ],
#                 [
#                     "1983",
#                     4513
#                 ],
#                 [
#                     "1984",
#                     5039
#                 ],
#                 [
#                     "1985",
#                     5956
#                 ],
#                 [
#                     "1986",
#                     7800
#                 ],
#                 [
#                     "1987",
#                     8908
#                 ],
#                 [
#                     "1988",
#                     8985
#                 ],
#                 [
#                     "1989",
#                     11371
#                 ],
#                 [
#                     "1990",
#                     16633
#                 ],
#                 [
#                     "1991",
#                     16513
#                 ],
#                 [
#                     "1992",
#                     14529
#                 ],
#                 [
#                     "1993",
#                     15253
#                 ],
#                 [
#                     "1994",
#                     14660
#                 ],
#                 [
#                     "1995",
#                     14067
#                 ],
#                 [
#                     "1996",
#                     14352
#                 ],
#                 [
#                     "1997",
#                     15259
#                 ],
#                 [
#                     "1998",
#                     14909
#                 ],
#                 [
#                     "1999",
#                     13551
#                 ],
#                 [
#                     "2000",
#                     12667
#                 ],
#                 [
#                     "2001",
#                     11313
#                 ],
#                 [
#                     "2002",
#                     11647
#                 ],
#                 [
#                     "2003",
#                     10828
#                 ],
#                 [
#                     "2004",
#                     10054
#                 ],
#                 [
#                     "2005",
#                     9894
#                 ],
#                 [
#                     "2006",
#                     10423
#                 ],
#                 [
#                     "2007",
#                     10546
#                 ],
#                 [
#                     "2008",
#                     9586
#                 ],
#                 [
#                     "2009",
#                     9151
#                 ],
#                 [
#                     "2010",
#                     8730
#                 ],
#                 [
#                     "2011",
#                     8565
#                 ],
#                 [
#                     "2012",
#                     8302
#                 ],
#                 [
#                     "2013",
#                     7689
#                 ],
#                 [
#                     "2014",
#                     7360
#                 ],
#                 [
#                     "2015",

# %%
name_trend('Kobe',data,gender='M',year=1920, dodge=100)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d59a663c19614172a5606280c3d1438f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d59a663c19614172a5606280c3d1438f = echarts.init(
#             document.getElementById('d59a663c19614172a5606280c3d1438f'), 'white', {renderer: 'canvas'});
#         var option_d59a663c19614172a5606280c3d1438f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Kobe",
#             "data": [
#                 5,
#                 9,
#                 87,
#                 350,
#                 1104,
#                 860,
#                 1432,
#                 1552,
#                 1392,
#                 1212,
#                 625,
#                 443,
#                 469,
#                 572,
#                 730,
#                 685,
#                 644,
#                 553,
#                 525,
#                 551,
#                 519,
#                 465,
#                 583,
#                 527
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "Kobe",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1989",
#                     105
#                 ],
#                 [
#                     "1995",
#                     109
#                 ],
#                 [
#                     "1996",
#                     187
#                 ],
#                 [
#                     "1997",
#                     450
#                 ],
#                 [
#                     "1998",
#                     1204
#                 ],
#                 [
#                     "1999",
#                     960
#                 ],
#                 [
#                     "2000",
#                     1532
#                 ],
#                 [
#                     "2001",
#                     1652
#                 ],
#                 [
#                     "2002",
#                     1492
#                 ],
#                 [
#                     "2003",
#                     1312
#                 ],
#                 [
#                     "2004",
#                     725
#                 ],
#                 [
#                     "2005",
#                     543
#                 ],
#                 [
#                     "2006",
#                     569
#                 ],
#                 [
#                     "2007",
#                     672
#                 ],
#                 [
#                     "2008",
#                     830
#                 ],
#                 [
#                     "2009",
#                     785
#                 ],
#                 [
#                     "2010",
#                     744
#                 ],
#                 [
#                     "2011",
#                     653
#                 ],
#                 [
#                     "2012",
#                     625
#                 ],
#                 [
#                     "2013",
#                     651
#                 ],
#                 [
#                     "2014",
#                     619
#                 ],
#                 [
#                     "2015",
#                     565
#                 ],
#                 [
#                     "2016",
#                     683
#                 ],
#                 [
#                     "2017",
#                     627
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Kobe",
#                 "Kobe"
#             ],
#             "selected": {
#                 "Kobe": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1989",
#                 "1995",
#                 "1996",
#                 "1997",
#                 "1998",
#                 "1999",
#                 "2000",
#                 "2001",
#                 "2002",
#                 "2003",
#                 "2004",
#                 "2005",
#                 "2006",
#                 "2007",
#                 "2008",
#                 "2009",
#                 "2010",
#                 "2011",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#         chart_d59a663c19614172a5606280c3d1438f.setOption(option_d59a663c19614172a5606280c3d1438f);
#     });
# </script>

# %% [markdown]
# - 影视明星：Emma, Scarlett

# %%
name_trend('Emma',data,gender='F',year=1980)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="f4a6756a5b3d4ad2a84811cecc179f00" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_f4a6756a5b3d4ad2a84811cecc179f00 = echarts.init(
#             document.getElementById('f4a6756a5b3d4ad2a84811cecc179f00'), 'white', {renderer: 'canvas'});
#         var option_f4a6756a5b3d4ad2a84811cecc179f00 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Emma",
#             "data": [
#                 533,
#                 534,
#                 562,
#                 551,
#                 676,
#                 944,
#                 1257,
#                 1588,
#                 1788,
#                 1935,
#                 2417,
#                 2592,
#                 3209,
#                 4104,
#                 4763,
#                 5044,
#                 6143,
#                 7739,
#                 10437,
#                 11728,
#                 12548,
#                 13307,
#                 16538,
#                 22704,
#                 21606,
#                 20339,
#                 19114,
#                 18372,
#                 18809,
#                 17892,
#                 17338,
#                 18797,
#                 20934,
#                 20936,
#                 20924,
#                 20435,
#                 19471,
#                 19738
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "Emma",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1980",
#                     1033
#                 ],
#                 [
#                     "1981",
#                     1034
#                 ],
#                 [
#                     "1982",
#                     1062
#                 ],
#                 [
#                     "1983",
#                     1051
#                 ],
#                 [
#                     "1984",
#                     1176
#                 ],
#                 [
#                     "1985",
#                     1444
#                 ],
#                 [
#                     "1986",
#                     1757
#                 ],
#                 [
#                     "1987",
#                     2088
#                 ],
#                 [
#                     "1988",
#                     2288
#                 ],
#                 [
#                     "1989",
#                     2435
#                 ],
#                 [
#                     "1990",
#                     2917
#                 ],
#                 [
#                     "1991",
#                     3092
#                 ],
#                 [
#                     "1992",
#                     3709
#                 ],
#                 [
#                     "1993",
#                     4604
#                 ],
#                 [
#                     "1994",
#                     5263
#                 ],
#                 [
#                     "1995",
#                     5544
#                 ],
#                 [
#                     "1996",
#                     6643
#                 ],
#                 [
#                     "1997",
#                     8239
#                 ],
#                 [
#                     "1998",
#                     10937
#                 ],
#                 [
#                     "1999",
#                     12228
#                 ],
#                 [
#                     "2000",
#                     13048
#                 ],
#                 [
#                     "2001",
#                     13807
#                 ],
#                 [
#                     "2002",
#                     17038
#                 ],
#                 [
#                     "2003",
#                     23204
#                 ],
#                 [
#                     "2004",
#                     22106
#                 ],
#                 [
#                     "2005",
#                     20839
#                 ],
#                 [
#                     "2006",
#                     19614
#                 ],
#                 [
#                     "2007",
#                     18872
#                 ],
#                 [
#                     "2008",
#                     19309
#                 ],
#                 [
#                     "2009",
#                     18392
#                 ],
#                 [
#                     "2010",
#                     17838
#                 ],
#                 [
#                     "2011",
#                     19297
#                 ],
#                 [
#                     "2012",
#                     21434
#                 ],
#                 [
#                     "2013",
#                     21436
#                 ],
#                 [
#                     "2014",
#                     21424
#                 ],
#                 [
#                     "2015",
#                     20935
#                 ],
#                 [
#                     "2016",
#                     19971
#                 ],
#                 [
#                     "2017",
#                     20238
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Emma",
#                 "Emma"
#             ],
#             "selected": {
#                 "Emma": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1980",
#                 "1981",
#                 "1982",
#                 "1983",
#                 "1984",
#                 "1985",
#                 "1986",
#                 "1987",
#                 "1988",
#                 "1989",
#                 "1990",
#                 "1991",
#                 "1992",
#                 "1993",
#                 "1994",
#                 "1995",
#                 "1996",
#                 "1997",
#                 "1998",
#                 "1999",
#                 "2000",
#                 "2001",
#                 "2002",
#                 "2003",

# %%
name_trend('Scarlett',data,gender='F',year=1980, dodge=200)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="99fb60103b344c0b9d17c86837f5cf48" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_99fb60103b344c0b9d17c86837f5cf48 = echarts.init(
#             document.getElementById('99fb60103b344c0b9d17c86837f5cf48'), 'white', {renderer: 'canvas'});
#         var option_99fb60103b344c0b9d17c86837f5cf48 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Scarlett",
#             "data": [
#                 121,
#                 113,
#                 87,
#                 92,
#                 124,
#                 112,
#                 137,
#                 151,
#                 131,
#                 138,
#                 167,
#                 151,
#                 204,
#                 250,
#                 235,
#                 272,
#                 248,
#                 230,
#                 254,
#                 245,
#                 227,
#                 237,
#                 290,
#                 326,
#                 538,
#                 733,
#                 1116,
#                 1582,
#                 1620,
#                 1920,
#                 2716,
#                 3558,
#                 4042,
#                 5050,
#                 6003,
#                 7125,
#                 7698,
#                 7679
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "Scarlett",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1980",
#                     321
#                 ],
#                 [
#                     "1981",
#                     313
#                 ],
#                 [
#                     "1982",
#                     287
#                 ],
#                 [
#                     "1983",
#                     292
#                 ],
#                 [
#                     "1984",
#                     324
#                 ],
#                 [
#                     "1985",
#                     312
#                 ],
#                 [
#                     "1986",
#                     337
#                 ],
#                 [
#                     "1987",
#                     351
#                 ],
#                 [
#                     "1988",
#                     331
#                 ],
#                 [
#                     "1989",
#                     338
#                 ],
#                 [
#                     "1990",
#                     367
#                 ],
#                 [
#                     "1991",
#                     351
#                 ],
#                 [
#                     "1992",
#                     404
#                 ],
#                 [
#                     "1993",
#                     450
#                 ],
#                 [
#                     "1994",
#                     435
#                 ],
#                 [
#                     "1995",
#                     472
#                 ],
#                 [
#                     "1996",
#                     448
#                 ],
#                 [
#                     "1997",
#                     430
#                 ],
#                 [
#                     "1998",
#                     454
#                 ],
#                 [
#                     "1999",
#                     445
#                 ],
#                 [
#                     "2000",
#                     427
#                 ],
#                 [
#                     "2001",
#                     437
#                 ],
#                 [
#                     "2002",
#                     490
#                 ],
#                 [
#                     "2003",
#                     526
#                 ],
#                 [
#                     "2004",
#                     738
#                 ],
#                 [
#                     "2005",
#                     933
#                 ],
#                 [
#                     "2006",
#                     1316
#                 ],
#                 [
#                     "2007",
#                     1782
#                 ],
#                 [
#                     "2008",
#                     1820
#                 ],
#                 [
#                     "2009",
#                     2120
#                 ],
#                 [
#                     "2010",
#                     2916
#                 ],
#                 [
#                     "2011",
#                     3758
#                 ],
#                 [
#                     "2012",
#                     4242
#                 ],
#                 [
#                     "2013",
#                     5250
#                 ],
#                 [
#                     "2014",
#                     6203
#                 ],
#                 [
#                     "2015",
#                     7325
#                 ],
#                 [
#                     "2016",
#                     7898
#                 ],
#                 [
#                     "2017",
#                     7879
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Scarlett",
#                 "Scarlett"
#             ],
#             "selected": {
#                 "Scarlett": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1980",
#                 "1981",
#                 "1982",
#                 "1983",
#                 "1984",
#                 "1985",
#                 "1986",
#                 "1987",
#                 "1988",
#                 "1989",
#                 "1990",
#                 "1991",
#                 "1992",
#                 "1993",
#                 "1994",
#                 "1995",
#                 "1996",
#                 "1997",
#                 "1998",
#                 "1999",
#                 "2000",
#                 "2001",
#                 "2002",
#                 "2003",
#                 "2004",
#                 "2005",
#                 "2006",

# %%
name_trend('Chandler',data,year=1976, dodge=100)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d61c0f95d1974d64bf804ea70848d40e" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d61c0f95d1974d64bf804ea70848d40e = echarts.init(
#             document.getElementById('d61c0f95d1974d64bf804ea70848d40e'), 'white', {renderer: 'canvas'});
#         var option_d61c0f95d1974d64bf804ea70848d40e = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7537",
#             "data": [
#                 66,
#                 48,
#                 63,
#                 70,
#                 66,
#                 70,
#                 90,
#                 88,
#                 118,
#                 120,
#                 142,
#                 198,
#                 224,
#                 301,
#                 396,
#                 467,
#                 553,
#                 661,
#                 704,
#                 1856,
#                 2185,
#                 1796,
#                 1952,
#                 2395,
#                 2131,
#                 1792,
#                 1417,
#                 1270,
#                 1130,
#                 870,
#                 753,
#                 674,
#                 607,
#                 579,
#                 524,
#                 615,
#                 595,
#                 674,
#                 730,
#                 730,
#                 652,
#                 590
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5973",
#             "data": [
#                 7,
#                 7,
#                 5,
#                 7,
#                 19,
#                 18,
#                 18,
#                 21,
#                 18,
#                 14,
#                 20,
#                 36,
#                 41,
#                 65,
#                 84,
#                 90,
#                 437,
#                 733,
#                 570,
#                 744,
#                 493,
#                 416,
#                 412,
#                 447,
#                 326,
#                 240,
#                 223,
#                 172,
#                 136,
#                 156,
#                 132,
#                 135,
#                 122,
#                 100,
#                 116,
#                 140,
#                 161,
#                 195,
#                 222,
#                 249,
#                 264,
#                 246
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u7537",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1976",
#                     166
#                 ],
#                 [
#                     "1977",
#                     148
#                 ],
#                 [
#                     "1978",
#                     163
#                 ],
#                 [
#                     "1979",
#                     170
#                 ],
#                 [
#                     "1980",
#                     166
#                 ],
#                 [
#                     "1981",
#                     170
#                 ],
#                 [
#                     "1982",
#                     190
#                 ],
#                 [
#                     "1983",
#                     188
#                 ],
#                 [
#                     "1984",
#                     218
#                 ],
#                 [
#                     "1985",
#                     220
#                 ],
#                 [
#                     "1986",
#                     242
#                 ],
#                 [
#                     "1987",
#                     298
#                 ],
#                 [
#                     "1988",
#                     324
#                 ],
#                 [
#                     "1989",
#                     401
#                 ],
#                 [
#                     "1990",
#                     496
#                 ],
#                 [
#                     "1991",
#                     567
#                 ],
#                 [
#                     "1992",
#                     653
#                 ],
#                 [
#                     "1993",
#                     761
#                 ],
#                 [
#                     "1994",
#                     804
#                 ],
#                 [
#                     "1995",
#                     1956
#                 ],
#                 [
#                     "1996",
#                     2285
#                 ],
#                 [
#                     "1997",
#                     1896
#                 ],
#                 [
#                     "1998",
#                     2052
#                 ],
#                 [
#                     "1999",
#                     2495
#                 ],
#                 [
#                     "2000",
#                     2231
#                 ],
#                 [
#                     "2001",
#                     1892
#                 ],
#                 [
#                     "2002",
#                     1517
#                 ],
#                 [
#                     "2003",
#                     1370
#                 ],
#                 [
#                     "2004",
#                     1230
#                 ],
#                 [
#                     "2005",
#                     970
#                 ],
#                 [
#                     "2006",
#                     853
#                 ],
#                 [
#                     "2007",
#                     774
#                 ],
#                 [
#                     "2008",
#                     707
#                 ],
#                 [
#                     "2009",
#                     679
#                 ],
#                 [
#                     "2010",
#                     624
#                 ],
#                 [
#                     "2011",
#                     715
#                 ],
#                 [
#                     "2012",
#                     695
#                 ],
#                 [
#                     "2013",
#                     774
#                 ],
#                 [
#                     "2014",
#                     830
#                 ],
#                 [
#                     "2015",
#                     830
#                 ],
#                 [
#                     "2016",
#                     752
#                 ],
#                 [
#                     "2017",
#                     690
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {

# %%
name_trend('Taylor',data,year=1976, dodge=100)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="7173265886ee4f04908dc37e5b16ae4a" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_7173265886ee4f04908dc37e5b16ae4a = echarts.init(
#             document.getElementById('7173265886ee4f04908dc37e5b16ae4a'), 'white', {renderer: 'canvas'});
#         var option_7173265886ee4f04908dc37e5b16ae4a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7537",
#             "data": [
#                 240,
#                 319,
#                 344,
#                 448,
#                 617,
#                 775,
#                 947,
#                 1055,
#                 1415,
#                 1794,
#                 2035,
#                 2431,
#                 3488,
#                 4856,
#                 6576,
#                 7967,
#                 8240,
#                 7688,
#                 6624,
#                 5519,
#                 4796,
#                 4332,
#                 3581,
#                 3071,
#                 2853,
#                 2309,
#                 1964,
#                 1828,
#                 1613,
#                 1576,
#                 1629,
#                 1430,
#                 1365,
#                 1093,
#                 955,
#                 899,
#                 886,
#                 824,
#                 695,
#                 656,
#                 641,
#                 571
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5973",
#             "data": [
#                 68,
#                 123,
#                 120,
#                 148,
#                 234,
#                 387,
#                 606,
#                 684,
#                 869,
#                 1050,
#                 1214,
#                 1706,
#                 2796,
#                 4069,
#                 7257,
#                 10253,
#                 14949,
#                 21266,
#                 20733,
#                 20425,
#                 19151,
#                 19503,
#                 18572,
#                 16905,
#                 15078,
#                 13690,
#                 11467,
#                 10308,
#                 9303,
#                 8671,
#                 8557,
#                 7960,
#                 8335,
#                 7582,
#                 5894,
#                 5188,
#                 4864,
#                 4135,
#                 3808,
#                 3744,
#                 3271,
#                 2692
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u7537",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1976",
#                     340
#                 ],
#                 [
#                     "1977",
#                     419
#                 ],
#                 [
#                     "1978",
#                     444
#                 ],
#                 [
#                     "1979",
#                     548
#                 ],
#                 [
#                     "1980",
#                     717
#                 ],
#                 [
#                     "1981",
#                     875
#                 ],
#                 [
#                     "1982",
#                     1047
#                 ],
#                 [
#                     "1983",
#                     1155
#                 ],
#                 [
#                     "1984",
#                     1515
#                 ],
#                 [
#                     "1985",
#                     1894
#                 ],
#                 [
#                     "1986",
#                     2135
#                 ],
#                 [
#                     "1987",
#                     2531
#                 ],
#                 [
#                     "1988",
#                     3588
#                 ],
#                 [
#                     "1989",
#                     4956
#                 ],
#                 [
#                     "1990",
#                     6676
#                 ],
#                 [
#                     "1991",
#                     8067
#                 ],
#                 [
#                     "1992",
#                     8340
#                 ],
#                 [
#                     "1993",
#                     7788
#                 ],
#                 [
#                     "1994",
#                     6724
#                 ],
#                 [
#                     "1995",
#                     5619
#                 ],
#                 [
#                     "1996",
#                     4896
#                 ],
#                 [
#                     "1997",
#                     4432
#                 ],
#                 [
#                     "1998",
#                     3681
#                 ],
#                 [
#                     "1999",
#                     3171
#                 ],
#                 [
#                     "2000",
#                     2953
#                 ],
#                 [
#                     "2001",
#                     2409
#                 ],
#                 [
#                     "2002",
#                     2064
#                 ],
#                 [
#                     "2003",
#                     1928
#                 ],
#                 [
#                     "2004",
#                     1713
#                 ],
#                 [
#                     "2005",
#                     1676
#                 ],
#                 [
#                     "2006",
#                     1729
#                 ],
#                 [
#                     "2007",
#                     1530
#                 ],
#                 [
#                     "2008",
#                     1465
#                 ],
#                 [
#                     "2009",
#                     1193
#                 ],
#                 [
#                     "2010",
#                     1055
#                 ],
#                 [
#                     "2011",
#                     999
#                 ],
#                 [
#                     "2012",
#                     986
#                 ],
#                 [
#                     "2013",
#                     924
#                 ],
#                 [
#                     "2014",
#                     795
#                 ],
#                 [
#                     "2015",
#                     756
#                 ],
#                 [
#                     "2016",
#                     741
#                 ],
#                 [
#                     "2017",
#                     671
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,

# %%
name_trend('Riley', data,year=1976, dodge=100)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="8974b14ef9ec4a21849275ed7008ba4a" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_8974b14ef9ec4a21849275ed7008ba4a = echarts.init(
#             document.getElementById('8974b14ef9ec4a21849275ed7008ba4a'), 'white', {renderer: 'canvas'});
#         var option_8974b14ef9ec4a21849275ed7008ba4a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7537",
#             "data": [
#                 106,
#                 117,
#                 167,
#                 162,
#                 164,
#                 181,
#                 199,
#                 225,
#                 253,
#                 333,
#                 403,
#                 476,
#                 528,
#                 676,
#                 813,
#                 865,
#                 1067,
#                 1376,
#                 1587,
#                 1918,
#                 2393,
#                 2833,
#                 3013,
#                 2970,
#                 3420,
#                 3651,
#                 3959,
#                 4076,
#                 4109,
#                 4110,
#                 4392,
#                 3969,
#                 4129,
#                 3785,
#                 3642,
#                 3457,
#                 2877,
#                 2552,
#                 2441,
#                 2086,
#                 1714,
#                 1454
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5973",
#             "data": [
#                 7,
#                 11,
#                 13,
#                 15,
#                 18,
#                 24,
#                 36,
#                 37,
#                 22,
#                 64,
#                 99,
#                 88,
#                 123,
#                 168,
#                 238,
#                 285,
#                 425,
#                 552,
#                 755,
#                 969,
#                 1148,
#                 1669,
#                 1877,
#                 2312,
#                 2552,
#                 3044,
#                 3905,
#                 4242,
#                 4982,
#                 5124,
#                 5055,
#                 5208,
#                 5768,
#                 5633,
#                 5537,
#                 5031,
#                 4825,
#                 4931,
#                 4790,
#                 5726,
#                 7131,
#                 6343
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u7537",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1976",
#                     206
#                 ],
#                 [
#                     "1977",
#                     217
#                 ],
#                 [
#                     "1978",
#                     267
#                 ],
#                 [
#                     "1979",
#                     262
#                 ],
#                 [
#                     "1980",
#                     264
#                 ],
#                 [
#                     "1981",
#                     281
#                 ],
#                 [
#                     "1982",
#                     299
#                 ],
#                 [
#                     "1983",
#                     325
#                 ],
#                 [
#                     "1984",
#                     353
#                 ],
#                 [
#                     "1985",
#                     433
#                 ],
#                 [
#                     "1986",
#                     503
#                 ],
#                 [
#                     "1987",
#                     576
#                 ],
#                 [
#                     "1988",
#                     628
#                 ],
#                 [
#                     "1989",
#                     776
#                 ],
#                 [
#                     "1990",
#                     913
#                 ],
#                 [
#                     "1991",
#                     965
#                 ],
#                 [
#                     "1992",
#                     1167
#                 ],
#                 [
#                     "1993",
#                     1476
#                 ],
#                 [
#                     "1994",
#                     1687
#                 ],
#                 [
#                     "1995",
#                     2018
#                 ],
#                 [
#                     "1996",
#                     2493
#                 ],
#                 [
#                     "1997",
#                     2933
#                 ],
#                 [
#                     "1998",
#                     3113
#                 ],
#                 [
#                     "1999",
#                     3070
#                 ],
#                 [
#                     "2000",
#                     3520
#                 ],
#                 [
#                     "2001",
#                     3751
#                 ],
#                 [
#                     "2002",
#                     4059
#                 ],
#                 [
#                     "2003",
#                     4176
#                 ],
#                 [
#                     "2004",
#                     4209
#                 ],
#                 [
#                     "2005",
#                     4210
#                 ],
#                 [
#                     "2006",
#                     4492
#                 ],
#                 [
#                     "2007",
#                     4069
#                 ],
#                 [
#                     "2008",
#                     4229
#                 ],
#                 [
#                     "2009",
#                     3885
#                 ],
#                 [
#                     "2010",
#                     3742
#                 ],
#                 [
#                     "2011",
#                     3557
#                 ],
#                 [
#                     "2012",
#                     2977
#                 ],
#                 [
#                     "2013",
#                     2652
#                 ],
#                 [
#                     "2014",
#                     2541
#                 ],
#                 [
#                     "2015",
#                     2186
#                 ],
#                 [
#                     "2016",
#                     1814
#                 ],
#                 [
#                     "2017",
#                     1554
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,

# %% [markdown]
# ## 6. 为什么同一发音的名字，有很多不同的拼写变体？
# - Catherine/Katharine
# [C|k]ath(.*)

# %%
Catherine = data['Name'][data['Name'].str.contains('^[C|K]ath(.*)')].unique()#取出名字里面为C/Kath*的名字并去重
Catherine
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# array(['Catherine', 'Katherine', 'Kathryn', 'Katharine', 'Catharine',
#        'Kathleen', 'Kathrine', 'Cathrine', 'Katheryn', 'Kathryne',
#        'Katharina', 'Katharyn', 'Kathyrn', 'Cathern', 'Cathryn',
#        'Kathern', 'Kathrina', 'Katherina', 'Katheryne', 'Katherin',
#        'Cathleen', 'Catheryn', 'Kathlyn', 'Catherina', 'Katherene',
#        'Kathaleen', 'Catherene', 'Cathryne', 'Katheleen', 'Kathy',
#        'Catheryne', 'Kathreen', 'Catherin', 'Kathlene', 'Kathrin',
#        'Kathalene', 'Kathelene', 'Kathlyne', 'Kathyleen', 'Kathren',
#        'Cather', 'Kathleene', 'Katharyne', 'Kathline', 'Cathren',
#        'Cathrin', 'Kathalyn', 'Katherne', 'Kathrene', 'Katherleen',
#        'Cathaleen', 'Catheline', 'Katheren', 'Katherlene', 'Kathie',
#        'Catherline', 'Cathy', 'Kathlean', 'Katheriene', 'Catha',
#        'Cathelene', 'Katholeen', 'Catheren', 'Catherne', 'Katha',
#        'Kathaline', 'Cathlyn', 'Katheline', 'Kathlynn', 'Cathaline',
#        'Cathreen', 'Katherline', 'Kathrean', 'Cathie', 'Kathelean',
#        'Kathrynn', 'Cathline', 'Kather', 'Kathlee', 'Cathlene', 'Kathey',
#        'Kathi', 'Cathey', 'Kathe', 'Kathye', 'Cathi', 'Cathe', 'Katheen',
#        'Catheleen', 'Kathee', 'Cathee', 'Katharin', 'Kathlen', 'Cathye',
#        'Cathay', 'Cathyrn', 'Kathay', 'Catharina', 'Cathyann',
#        'Kathylene', 'Cathalene', 'Kathyanne', 'Cathlean', 'Katheran',
#        'Cathlin', 'Kathileen', 'Kathleenmary', 'Cathyleen', 'Kathyann',
#        'Kathyrne', 'Kathyjo', 'Cathirine', 'Kathran', 'Kathyren',
#        'Kathyrine', 'Kathleeen', 'Kathia', 'Kathry', 'Kathyn', 'Kathyern',
#        'Kath', 'Cath', 'Kathllen', 'Katheine', 'Kathyy', 'Cathrina',
#        'Kathleena', 'Kathlena', 'Cathlena', 'Cathyjo', 'Kathina',
#        'Kathya', 'Cathalina', 'Kathiria', 'Cathia', 'Kathalina',
#        'Kathyria', 'Kathelyn', 'Kathrynne', 'Cathylee', 'Kathlina',
#        'Kathlin', 'Kathleenann', 'Katherinne', 'Kathiana', 'Kathrynanne',
#        'Kathrynann', 'Cathlina', 'Cathal', 'Kathan', 'Cathan', 'Kathen',
#        'Cathrynn', 'Kathaleya', 'Kathalia', 'Cathaleya', 'Cathalia',
#        'Katherynn', 'Kathir'], dtype=object)

# %%
Catherine_data = data[data['Name'].isin(Catherine)].groupby('Name').Count.sum()#名字在里面的，按名字汇总，算Count汇总

# %%
name = list(Catherine_data.index)
value = list(Catherine_data.values)
wordcloud = WordCloud(width=1000, height=600,background_color='#feeeed')  # feeeed #设置图片格式
#wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
frequency={key:val for key in name for val in value}#转成dict
wordcloud.generate_from_frequencies(frequency)#画词云图
plt.imshow(wordcloud)#画出图片

# %%
Emily = data['Name'][data['Name'].str.contains('Emil(.*)')].unique()#Emil*
# Out:
# F:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.

# %%
Emily_data = data[data['Name'].isin(Emily)].groupby('Name').Count.sum()

# %%
name = list(Emily_data.index)
value = list(Emily_data.values)
wordcloud = WordCloud(width=1000, height=600,background_color='#feeeed')  # feeeed
# wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
frequency={key:val for key in name for val in value}#转成dict
wordcloud.generate_from_frequencies(frequency)
plt.imshow(wordcloud)#画出图片

# %% [markdown]
# ## 7. 一些具有特殊含义的名字，有多少人取？

# %%
# def name_trend2(name, data, gender, dodge=100):
#     name_data = data[(data['Name']==name)&(data['Gender']==gender)]
#     attr = list(name_data['Year'].values)
#     v1 = name_data['Count'].values

#     bar = Bar(name)
#     bar.add("", attr, list(v1), legend_text_size=18,xaxis_label_textsize=18,yaxis_label_textsize=18)
    
#     line = Line()
#     line.add("", attr, list(v1 + dodge))
    
#     overlap = Overlap()
#     overlap.add(bar)
#     overlap.add(line)
#     return overlap

def name_trend2(name, data, gender, dodge=100):
    name_data = data[(data['Name']==name)&(data['Gender']==gender)]#取出特定名字和性别的数据
    attr = list(name_data['Year'].values)#取出数据里的年份
    attr=[str(i) for i in attr]#转字符串
    v1 = name_data['Count'].values#取出count值
    v1= [int(i) for i in v1]#转int
    v1d= [int(i)+dodge for i in v1]#转int
    bar = Bar()#画bar图
    bar.add_xaxis(attr)#bar的横坐标
    bar.add_yaxis(name, list(v1))#第一组数据
    bar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))#不展示点标签
    
    line = Line()
    line.add_xaxis(attr)#line的横坐标
    line.add_yaxis(name, v1d,label_opts=opts.LabelOpts(is_show=False))#不加标签)
        
    bar.overlap(line)
    return bar.render_notebook()#画图

# %%
name_trend2('Dick',data,gender='M', dodge=50)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="b02a86df5abb449794a22f8792ff4f1f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_b02a86df5abb449794a22f8792ff4f1f = echarts.init(
#             document.getElementById('b02a86df5abb449794a22f8792ff4f1f'), 'white', {renderer: 'canvas'});
#         var option_b02a86df5abb449794a22f8792ff4f1f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Dick",
#             "data": [
#                 25,
#                 20,
#                 14,
#                 24,
#                 37,
#                 27,
#                 23,
#                 27,
#                 27,
#                 22,
#                 31,
#                 18,
#                 24,
#                 20,
#                 25,
#                 22,
#                 27,
#                 23,
#                 29,
#                 30,
#                 45,
#                 21,
#                 35,
#                 18,
#                 24,
#                 36,
#                 32,
#                 38,
#                 34,
#                 46,
#                 52,
#                 37,
#                 77,
#                 94,
#                 129,
#                 167,
#                 221,
#                 220,
#                 251,
#                 269,
#                 329,
#                 349,
#                 363,
#                 350,
#                 442,
#                 563,
#                 650,
#                 775,
#                 834,
#                 841,
#                 940,
#                 992,
#                 1053,
#                 1045,
#                 1131,
#                 1093,
#                 1088,
#                 1008,
#                 935,
#                 876,
#                 911,
#                 894,
#                 860,
#                 856,
#                 808,
#                 758,
#                 828,
#                 755,
#                 552,
#                 340,
#                 269,
#                 246,
#                 215,
#                 215,
#                 166,
#                 182,
#                 192,
#                 201,
#                 234,
#                 219,
#                 186,
#                 184,
#                 147,
#                 128,
#                 110,
#                 100,
#                 65,
#                 74,
#                 62,
#                 57,
#                 52,
#                 38,
#                 29,
#                 35,
#                 33,
#                 23,
#                 20,
#                 19,
#                 21,
#                 17,
#                 20,
#                 9,
#                 17,
#                 19,
#                 11,
#                 13,
#                 10,
#                 12,
#                 10,
#                 10,
#                 5,
#                 6,
#                 6,
#                 6,
#                 6,
#                 6,
#                 5
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "Dick",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1880",
#                     75
#                 ],
#                 [
#                     "1881",
#                     70
#                 ],
#                 [
#                     "1882",
#                     64
#                 ],
#                 [
#                     "1883",
#                     74
#                 ],
#                 [
#                     "1884",
#                     87
#                 ],
#                 [
#                     "1885",
#                     77
#                 ],
#                 [
#                     "1886",
#                     73
#                 ],
#                 [
#                     "1887",
#                     77
#                 ],
#                 [
#                     "1888",
#                     77
#                 ],
#                 [
#                     "1889",
#                     72
#                 ],
#                 [
#                     "1890",
#                     81
#                 ],
#                 [
#                     "1891",
#                     68
#                 ],
#                 [
#                     "1892",
#                     74
#                 ],
#                 [
#                     "1893",
#                     70
#                 ],
#                 [
#                     "1894",
#                     75
#                 ],
#                 [
#                     "1895",
#                     72
#                 ],
#                 [
#                     "1896",
#                     77
#                 ],
#                 [
#                     "1897",
#                     73
#                 ],
#                 [
#                     "1898",
#                     79
#                 ],
#                 [
#                     "1899",
#                     80
#                 ],
#                 [
#                     "1900",
#                     95
#                 ],
#                 [
#                     "1901",
#                     71
#                 ],
#                 [
#                     "1902",
#                     85
#                 ],
#                 [
#                     "1903",
#                     68
#                 ],
#                 [
#                     "1904",
#                     74
#                 ],
#                 [
#                     "1905",
#                     86
#                 ],
#                 [
#                     "1906",
#                     82
#                 ],
#                 [
#                     "1907",
#                     88
#                 ],
#                 [
#                     "1908",
#                     84
#                 ],
#                 [
#                     "1909",
#                     96
#                 ],
#                 [
#                     "1910",
#                     102
#                 ],
#                 [
#                     "1911",
#                     87
#                 ],
#                 [
#                     "1912",
#                     127
#                 ],
#                 [
#                     "1913",
#                     144
#                 ],
#                 [
#                     "1914",
#                     179
#                 ],
#                 [
#                     "1915",
#                     217
#                 ],
#                 [
#                     "1916",
#                     271
#                 ],
#                 [
#                     "1917",
#                     270
#                 ],
#                 [
#                     "1918",
#                     301
#                 ],
#                 [
#                     "1919",
#                     319
#                 ],
#                 [
#                     "1920",
#                     379
#                 ],
#                 [
#                     "1921",
#                     399
#                 ],
#                 [
#                     "1922",
#                     413
#                 ],
#                 [
#                     "1923",
#                     400
#                 ],
#                 [

# %%
name_trend2('Dong', data, gender='M', dodge=1)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="d69786b6524e4a27b6cee820babbb821" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_d69786b6524e4a27b6cee820babbb821 = echarts.init(
#             document.getElementById('d69786b6524e4a27b6cee820babbb821'), 'white', {renderer: 'canvas'});
#         var option_d69786b6524e4a27b6cee820babbb821 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Dong",
#             "data": [
#                 5,
#                 5,
#                 5,
#                 6,
#                 6,
#                 5,
#                 5,
#                 7,
#                 7,
#                 5,
#                 10,
#                 10,
#                 12,
#                 17,
#                 9,
#                 8,
#                 13,
#                 6,
#                 11,
#                 7,
#                 13,
#                 12,
#                 19,
#                 13,
#                 16,
#                 12,
#                 11,
#                 8,
#                 5,
#                 5,
#                 5,
#                 8,
#                 9,
#                 5,
#                 7,
#                 5,
#                 6
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "Dong",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1956",
#                     6
#                 ],
#                 [
#                     "1964",
#                     6
#                 ],
#                 [
#                     "1965",
#                     6
#                 ],
#                 [
#                     "1967",
#                     7
#                 ],
#                 [
#                     "1968",
#                     7
#                 ],
#                 [
#                     "1969",
#                     6
#                 ],
#                 [
#                     "1970",
#                     6
#                 ],
#                 [
#                     "1972",
#                     8
#                 ],
#                 [
#                     "1976",
#                     8
#                 ],
#                 [
#                     "1977",
#                     6
#                 ],
#                 [
#                     "1979",
#                     11
#                 ],
#                 [
#                     "1980",
#                     11
#                 ],
#                 [
#                     "1981",
#                     13
#                 ],
#                 [
#                     "1982",
#                     18
#                 ],
#                 [
#                     "1983",
#                     10
#                 ],
#                 [
#                     "1984",
#                     9
#                 ],
#                 [
#                     "1985",
#                     14
#                 ],
#                 [
#                     "1986",
#                     7
#                 ],
#                 [
#                     "1987",
#                     12
#                 ],
#                 [
#                     "1988",
#                     8
#                 ],
#                 [
#                     "1989",
#                     14
#                 ],
#                 [
#                     "1990",
#                     13
#                 ],
#                 [
#                     "1991",
#                     20
#                 ],
#                 [
#                     "1992",
#                     14
#                 ],
#                 [
#                     "1993",
#                     17
#                 ],
#                 [
#                     "1994",
#                     13
#                 ],
#                 [
#                     "1995",
#                     12
#                 ],
#                 [
#                     "1996",
#                     9
#                 ],
#                 [
#                     "1997",
#                     6
#                 ],
#                 [
#                     "1998",
#                     6
#                 ],
#                 [
#                     "1999",
#                     6
#                 ],
#                 [
#                     "2000",
#                     9
#                 ],
#                 [
#                     "2001",
#                     10
#                 ],
#                 [
#                     "2002",
#                     6
#                 ],
#                 [
#                     "2003",
#                     8
#                 ],
#                 [
#                     "2012",
#                     6
#                 ],
#                 [
#                     "2017",
#                     7
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Dong",
#                 "Dong"
#             ],
#             "selected": {
#                 "Dong": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1956",
#                 "1964",
#                 "1965",
#                 "1967",
#                 "1968",
#                 "1969",
#                 "1970",
#                 "1972",
#                 "1976",
#                 "1977",
#                 "1979",
#                 "1980",
#                 "1981",
#                 "1982",
#                 "1983",
#                 "1984",
#                 "1985",
#                 "1986",
#                 "1987",
#                 "1988",
#                 "1989",
#                 "1990",
#                 "1991",
#                 "1992",
#                 "1993",
#                 "1994",
#                 "1995",
#                 "1996",
#                 "1997",
#                 "1998",
#                 "1999",
#                 "2000",
#                 "2001",
#                 "2002",
#                 "2003",
#                 "2012",
#                 "2017"
#             ]
#         }
#     ],
#     "

# %%
name_trend2('Cherry',data,gender='F', dodge=10)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="2394682bc70b405cb1c1730f5a2d43de" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_2394682bc70b405cb1c1730f5a2d43de = echarts.init(
#             document.getElementById('2394682bc70b405cb1c1730f5a2d43de'), 'white', {renderer: 'canvas'});
#         var option_2394682bc70b405cb1c1730f5a2d43de = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Cherry",
#             "data": [
#                 6,
#                 5,
#                 7,
#                 5,
#                 7,
#                 10,
#                 7,
#                 5,
#                 10,
#                 8,
#                 10,
#                 13,
#                 10,
#                 8,
#                 15,
#                 10,
#                 13,
#                 11,
#                 13,
#                 8,
#                 13,
#                 8,
#                 15,
#                 6,
#                 10,
#                 12,
#                 11,
#                 11,
#                 18,
#                 13,
#                 20,
#                 12,
#                 26,
#                 38,
#                 25,
#                 33,
#                 44,
#                 34,
#                 34,
#                 54,
#                 42,
#                 43,
#                 62,
#                 75,
#                 52,
#                 58,
#                 68,
#                 77,
#                 80,
#                 74,
#                 102,
#                 78,
#                 94,
#                 92,
#                 63,
#                 81,
#                 90,
#                 87,
#                 112,
#                 93,
#                 144,
#                 146,
#                 197,
#                 219,
#                 318,
#                 354,
#                 343,
#                 292,
#                 246,
#                 268,
#                 300,
#                 265,
#                 261,
#                 251,
#                 302,
#                 299,
#                 232,
#                 216,
#                 222,
#                 185,
#                 163,
#                 161,
#                 175,
#                 140,
#                 112,
#                 174,
#                 145,
#                 150,
#                 157,
#                 155,
#                 143,
#                 139,
#                 124,
#                 117,
#                 106,
#                 128,
#                 103,
#                 103,
#                 108,
#                 82,
#                 89,
#                 67,
#                 83,
#                 67,
#                 72,
#                 59,
#                 58,
#                 45,
#                 53,
#                 60,
#                 54,
#                 42,
#                 34,
#                 30,
#                 31,
#                 29,
#                 32,
#                 22,
#                 31,
#                 21,
#                 15,
#                 19,
#                 22,
#                 29,
#                 31,
#                 38,
#                 32,
#                 24,
#                 21,
#                 26,
#                 39,
#                 35,
#                 46,
#                 43,
#                 40,
#                 26
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "Cherry",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "1880",
#                     16
#                 ],
#                 [
#                     "1881",
#                     15
#                 ],
#                 [
#                     "1882",
#                     17
#                 ],
#                 [
#                     "1883",
#                     15
#                 ],
#                 [
#                     "1884",
#                     17
#                 ],
#                 [
#                     "1885",
#                     20
#                 ],
#                 [
#                     "1888",
#                     17
#                 ],
#                 [
#                     "1889",
#                     15
#                 ],
#                 [
#                     "1890",
#                     20
#                 ],
#                 [
#                     "1891",
#                     18
#                 ],
#                 [
#                     "1892",
#                     20
#                 ],
#                 [
#                     "1893",
#                     23
#                 ],
#                 [
#                     "1894",
#                     20
#                 ],
#                 [
#                     "1895",
#                     18
#                 ],
#                 [
#                     "1896",
#                     25
#                 ],
#                 [
#                     "1897",
#                     20
#                 ],
#                 [
#                     "1898",
#                     23
#                 ],
#                 [
#                     "1899",
#                     21
#                 ],
#                 [
#                     "1900",
#                     23
#                 ],
#                 [
#                     "1901",
#                     18
#                 ],
#                 [
#                     "1902",
#                     23
#                 ],
#                 [
#                     "1903",
#                     18
#                 ],
#                 [
#                     "1904",
#                     25
#                 ],
#                 [
#                     "1905",
#                     16
#                 ],
#                 [
#                     "1906",
#                     20
#                 ],
#                 [
#                     "1907",
#                     22
#                 ],
#                 [
#                     "1908",
#                     21
#                 ],
#                 [
#                     "1909",
#                     21
#                 ],
#                 [
#                     "1910",
#                     28
#                 ],
#                 [
#                     "1911",
#                     23
#                 ],
#                 [
#                     "1912",
#                     30
#                 ],
#                 [
#                     "1913",
#                     22
#                 ],
#                 [
#                     "1914",
#                     36
#                 ],
#                 [
#                     "1915",
#                     48
#                 ],
#                 [
#                     "1916",
#                     35
#                 ],
#                 [
#                     "1917",
#                     43
#                 ],
#                 [
#                     "1918",
#                     54
#                 ],
#                 [
#                     "1919",
#                     44
#                 ],
#                 [
#                     "1920",
#                     44
#                 ],
#                 [
#                     "1921",
#                     64
#                 ],
#                 [

# %% [markdown]
# ## 8. 一些特殊的名字

# %%
class Solution:
    # @return a string
    def getlongestpalindrome(self, s, l, r):
        while l >= 0 and r < len(s) and s[l] == s[r]:
            l -= 1; r += 1
        return s[l+1 : r]
    def longestPalindrome(self, s):
        palindrome = ''
        for i in range(len(s)):
            len1 = len(self.getlongestpalindrome(s, i, i))
            if len1 > len(palindrome): palindrome = self.getlongestpalindrome(s, i, i)
            len2 = len(self.getlongestpalindrome(s, i, i + 1))
            if len2 > len(palindrome): palindrome = self.getlongestpalindrome(s, i, i + 1)
        return True if len(palindrome) > 5 else False

# %%
a = Solution()

# %%
a.longestPalindrome('alfrederfl')
# Out:
# True

# %%
all_name = data['Name'].unique()

# %%
palindrome_name = []
for name in all_name:
    if a.longestPalindrome(name):
        palindrome_name.append(name)

# %%
palindrome_data = data[data['Name'].isin(palindrome_name)].groupby('Name').Count.sum()

# %%
name = list(palindrome_data.index)
value = list(palindrome_data.values)
wordcloud = WordCloud(width=1000, height=600,background_color='#feeeed')  # feeeed
#wordcloud.add("", name, value, word_size_range=[20, 100],shape='diamond')
frequency={key:val for key in name for val in value}#转成dict
wordcloud.generate_from_frequencies(frequency)
plt.imshow(wordcloud)#画出图片
